# %% [markdown]
# # UBS_lauzhack - Entity resolution model

# %% [markdown]
# ## 1. Pre-processing

# %% [markdown]
# Observed the given dataset and apply the proper transformations to the data in order to better anlyse it and create the model.

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter
from IPython.core.interactiveshell import InteractiveShell
import warnings


InteractiveShell.ast_node_interactivity = "all"
#pd.set_option('precision', 3)
display.precision = 3
sns.set()
warnings.filterwarnings('ignore')

# extra imports
from pandas import read_csv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import LocalOutlierFactor
from sklearn import preprocessing
#from statsmodels.genmod.generalized_linear_model import GLM
from pandas.plotting import scatter_matrix
from scipy.stats import boxcox

# %%
# Read the CSV files from the 'data' subfolder
account_booking_df = pd.read_csv('data/account_booking_train.csv')
external_parties_df = pd.read_csv('data/external_parties_train.csv')

# %%
# Combine the tables with merge using 
combined_data = pd.merge(account_booking_df, external_parties_df, on='transaction_reference_id', how='inner')

# %%
#Null count of each variables to know which ones are more relevant to analyze
combined_data.isnull().sum()
# Out:
# transaction_reference_id            0
# debit_credit_indicator              0
# account_id                          0
# transaction_amount                  0
# transaction_currency                0
# transaction_date                    0
# party_role                          0
# party_info_unstructured             0
# parsed_name                         0
# parsed_address_street_name        739
# parsed_address_street_number     3030
# parsed_address_unit             11064
# parsed_address_postal_code       3480
# parsed_address_city              1168
# parsed_address_state             9107
# parsed_address_country           6490
# party_iban                       3399
# party_phone                      5000
# external_id                         0
# dtype: int64

# %%
# Drop the columns that have more than 50% of missing values and irrelevant information

## External parties data

irrelevant_cols_external = ['party_info_unstructured', 'parsed_address_unit', 'parsed_address_state', 'parsed_address_country']
external_parties_df.drop(columns=irrelevant_cols_external, inplace=True, errors='ignore')

## Accounts booking data
duplicate_ids = account_booking_df[account_booking_df.duplicated(subset='transaction_reference_id', keep=False)]
account_booking_df = account_booking_df[~account_booking_df['transaction_reference_id'].isin(duplicate_ids['transaction_reference_id'])]

irrelevant_cols_booking = ['debit_credit_indicator']
account_booking_df.drop(columns=irrelevant_cols_booking, inplace=True, errors='ignore')

# Merge the two dataframes

merged_df = pd.merge(external_parties_df, account_booking_df, on='transaction_reference_id', how='inner')

merged_df.to_csv('merged_data_cleaned.csv', index=False)

# %%
honorifics = ['Mr. ', 'Ms. ', 'Mrs. ', 'Miss ', 'Dr. ', 'Prof. ', 'Rev. ', 'Hon. ', 'mr. ', 'ms. ', 'mrs. ', 'miss ', 'dr. ', 'prof. ', 'rev. ', 'hon. ']
for honorific in honorifics:
    merged_df['parsed_name'] = merged_df['parsed_name'].str.replace(honorific, '')


def delete_duplicates(name):
    def remove_duplicates(text):
        words = text.split()
        seen = set()
        result = []
        for word in words:
            if word.lower() not in seen:
                seen.add(word.lower())
                result.append(word)
        return ' '.join(result)
    
    name['parsed_name'] = name['parsed_name'].apply(remove_duplicates)
    return name

merged_df = delete_duplicates(merged_df)

# %%
from metaphone import doublemetaphone

def apply_metaphone(value):
    if isinstance(value, list) or isinstance(value, np.ndarray):  
        return np.nan  
    if pd.isna(value) or not isinstance(value, str):  
        return np.nan
    return doublemetaphone(value.strip().lower())[0] 

def split_and_metaphone(full_name):
    """
    Divide un nombre completo en sus partes (palabras), aplica Metaphone a cada parte,
    y las junta nuevamente con espacios.
    """
    if pd.isna(full_name) or not isinstance(full_name, str):  
        return np.nan

    parts = full_name.strip().split()

    return ' '.join(apply_metaphone(part) for part in parts)

merged_df['parsed_name'] = merged_df['parsed_name'].apply(split_and_metaphone)

print(merged_df['parsed_name'].head())
# Out:
# 0          MR M0
# 1         ASN KM
# 2      RPRSN JRR
# 3    ASKSSNLSN K
# 4      MMJJ PT A
# Name: parsed_name, dtype: object

# %%
merged_df['parsed_address_street_name'] = merged_df['parsed_address_street_name'].apply(split_and_metaphone)

print(merged_df['parsed_address_street_name'].head())

merged_df.to_csv('merged_data_cleaned.csv', index=False)
# Out:
# 0       ANJL PRKS
# 1         NR0 MKL
# 2    RXL KRSNKPTT
# 3        PRTS ST
# 4    JN LK SS KLN
# Name: parsed_address_street_name, dtype: object

# %%
# Función para calcular similitudes con TF-IDF

# Reemplazar valores faltantes de direcciones
merged_df['parsed_address_street_name'].fillna(merged_df['parsed_address_city'].fillna('MISSING'), inplace=True)

def calculate_similarity(df, column1, column2, column3):
    vectorizer = TfidfVectorizer()
    
    # Rellenamos los valores faltantes con un valor temporal
    df[column1].fillna('MISSING', inplace=True)
    df[column2].fillna('MISSING', inplace=True)
    df[column3].fillna('MISSING', inplace=True)
    df[column3] = df[column3].astype(str)

    # Combinamos las dos columnas en una nueva
    combined_column = df[column1] + " " + df[column2] + " " + df[column3]
    
    # Creamos la matriz TF-IDF
    tfidf_matrix = vectorizer.fit_transform(combined_column)
    
    # Calculamos la matriz de similitud del coseno
    cosine_sim = cosine_similarity(tfidf_matrix)
    
    # Opcional: Penaliza similitud para valores originalmente faltantes
    missing_mask = df[column1].isna().values | df[column2].isna().values
    cosine_sim[missing_mask, :] = 0
    cosine_sim[:, missing_mask] = 0
    
    return cosine_sim


# Función de blocking
def create_block_key(value, prefix_length=5):
    if pd.isna(value):  # Maneja valores faltantes
        return 'MISSING'
    return value[:prefix_length].lower()

# Aplica el bloqueo en la columna deseada
merged_df['block'] = merged_df['parsed_name'].apply(create_block_key, prefix_length=3)

def create_combined_block(row):
    # Combina prefijos de varias columnas
    name_key = create_block_key(row['parsed_name'], prefix_length=3)
    address_key = create_block_key(row['parsed_address_street_name'], prefix_length=3)
    account_id = create_block_key(str(row['account_id']), prefix_length=3)
    return f"{name_key}_{address_key}_{account_id}"

merged_df['block'] = merged_df.apply(create_combined_block, axis=1)
blocks = merged_df.groupby('block')


# Procesar cada bloque


merged_df['parsed_address_street_name'].fillna(
merged_df['parsed_address_city'].fillna('MISSING'), inplace=True
)

results = []

# En el bucle de procesamiento de bloques, en lugar de calcular solo la similitud de `parsed_name`, ahora usaremos las dos columnas
for block_name, block_data in blocks:
    print(f"Processing block: {block_name}")
    
    if len(block_data) < 2:
        block_data['external_id'] = range(len(results), len(results) + len(block_data))
        results.append(block_data)
        continue

    # Similaridad para 'parsed_name' y 'parsed_address_street_name'
    name_and_address_similarity = calculate_similarity(block_data, 'parsed_name', 'parsed_address_street_name', 'account_id')
    
    # Asegúrate de que los valores de la matriz de similitud estén en el rango [0, 1]
    name_and_address_similarity = np.clip(name_and_address_similarity, 0, 1)
    
    # Convertimos la matriz de similitud en distancias
    distance_matrix = 1 - name_and_address_similarity
    
    # Aplicamos DBSCAN
    db = DBSCAN(eps=0.3, min_samples=2, metric='precomputed')
    clusters = db.fit_predict(distance_matrix)
    
    # Asignamos clusters como 'external_id'
    block_data['external_id'] = clusters + len(results)  # Evita conflictos entre bloques
    results.append(block_data)


# Combinar los resultados de todos los bloques
final_df = pd.concat(results, ignore_index=True)
cluster_sizes = final_df['external_id'].value_counts()
valid_clusters = cluster_sizes[cluster_sizes > 1].index

# Filtramos las filas que pertenecen a esos clusters
filtered_df = final_df[final_df['external_id'].isin(valid_clusters)]
filtered_df = filtered_df[['external_id', 'transaction_reference_id']]

filtered_df.to_excel('filtered_clusters.xlsx', index=False)

# Visualizar el tamaño de cada cluster
cluster_sizes2 = filtered_df['external_id'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=cluster_sizes2.index, y=cluster_sizes2.values)
plt.title('Distribución de Clusters')
plt.xlabel('Cluster ID')
plt.ylabel('Tamaño del Cluster')
plt.show()
# Out:
# Processing block:  0r_rtr_299
# Processing block:  ak_rt _212
# Processing block:  al_jsk_215
# Processing block:  al_nn _217
# Processing block:  al_tlr_297
# Processing block:  am_n n_203
# Processing block:  ar_ant_239
# Processing block:  as_ as_211
# Processing block:  as_ as_290
# Processing block:  at_hnt_209
# Processing block:  fr_ fr_288
# Processing block:  hk_krs_202
# Processing block:  hk_krs_245
# Processing block:  hk_lrn_254
# Processing block:  hk_mrk_211
# Processing block:  hk_p0 _262
# Processing block:  hk_tf _271
# Processing block:  hr_krs_222
# Processing block:  hr_ls _294
# Processing block:  hr_m0 _204
# Processing block:  hr_rtr_251
# Processing block:  jn_a_203
# Processing block:  jn_lrn_229
# Processing block:  jn_plk_286
# Processing block:  jn_rsl_258
# Processing block:  jn_tms_284
# Processing block:  jn_tnl_267
# Processing block:  k0_jks_260
# Processing block:  kn_rpk_234
# Processing block:  kp_tmp_299
# Processing block:  kr_knk_200
# Processing block:  kr_prn_200
# Processing block:  kr_prn_265
# Processing block:  lr_nkl_247
# Processing block:  m0_ kr_203
# Processing block:  m0_ m0_238
# Processing block:  m0_ m0_270
# Processing block:  mk_ kr_265
# Processing block:  mk_jn _261
# Processing block:  mk_krs_217
# Processing block:  mk_n l_287
# Processing block:  mk_tn _227
# Processing block:  mn_ ts_207
# Processing block:  mn_ts _256
# Processing block:  mt_jks_252
# Processing block:  nl_tan_202
# Processing block:  p_mxl_204
# Processing block:  rp_rxl_226
# Processing block:  rp_rxl_236
# Processing block:  rp_rxl_269
# Processing block:  sm_atm_284
# Processing block:  sm_prn_281
# Processing block:  tf_kpl_292
# Processing block:  tk_jms_222
# Processing block:  tk_prn_237
# Processing block:  tk_prn_239
# Processing block:  tn_ant_247
# Processing block: 0js_at _223
# Processing block: 0ms_lsl_240
# Processing block: 0ms_tkm_254
# Processing block: 0r _krs_264
# Processing block: 0rn_hol_214
# Processing block: 0rn_hrn_259
# Processing block: 0rn_jxl_263
# Processing block: 0rn_mlt_203
# Processing block: 0rn_rsm_276
# Processing block: 0rs_har_225
# Processing block: 0rs_har_238
# Processing block: 0rs_har_262
# Processing block: 0rs_hrs_295
# Processing block: 0rs_jns_230
# Processing block: 0rs_krs_200
# Processing block: 0rs_mis_252
# Processing block: 0tr_ant_294
# Processing block: 0tr_kns_207
# Processing block: 0tr_mis_282
# Processing block: 0tr_mkl_240
# Processing block: 0tr_spr_217
# Processing block: 0tr_sts_207
# Processing block: a h_k p_264
# Processing block: a l_jnf_269
# Processing block: a l_tft_245
# Processing block: a l_tft_254
# Processing block: a n_pns_274
# Processing block: a p_alm_270
# Processing block: a p_peo_273
# Processing block: a p_stf_212
# Processing block: a p_stf_218
# Processing block: a s_flr_225
# Processing block: a t_krn_206
# Processing block: a t_rt _241
# Processing block: a0l_frn_268
# Processing block: aa _ sm_253
# Processing block: aa _aa _230
# Processing block: aa _aa _232
# Processing block: aa _aa _273
# Processing block: aa _afl_251
# Processing block: aa _afn_234
# Processing block: aa _afn_241
# Processing block: aa _afn_285
# Processing block: aa _afr_214
# Processing block: aa _akl_205
# Processing block: aa _akl_215
# Processing block: aa _als_268
# Processing block: aa _am _233
# Processing block: aa _an _231
# Processing block: aa _an _258
# Processing block: aa _an _266
# Processing block: aa _an _296
# Processing block: aa _an _298
# Processing block: aa _ank_205
# Processing block: aa _at _210
# Processing block: aa _ats_223
# Processing block: aa _coo_233
# Processing block: aa _fle_264
# Processing block: aa _flr_286
# Processing block: aa _frn_218
# Processing block: aa _frn_293
# Processing block: aa _hnt_238
# Processing block: aa _hpk_285
# Processing block: aa _hpk_293
# Processing block: aa _hpr_255
# Processing block: aa _hrn_222
# Processing block: aa _jkp_237
# Processing block: aa _jm _224
# Processing block: aa _jn _213
# Processing block: aa _jn0_238
# Processing block: aa _jnf_290
# Processing block: aa _jnm_245
# Processing block: aa _jns_204
# Processing block: aa _jns_207
# Processing block: aa _jns_214
# Processing block: aa _jns_226
# Processing block: aa _jns_232
# Processing block: aa _jns_249
# Processing block: aa _jns_271
# Processing block: aa _jns_295
# Processing block: aa _jrm_263
# Processing block: aa _jsn_207
# Processing block: aa _jx _285
# Processing block: aa _k0_208
# Processing block: aa _kl _223
# Processing block: aa _klm_250
# Processing block: aa _klt_244
# Processing block: aa _klt_258
# Processing block: aa _kn0_215
# Processing block: aa _kps_221
# Processing block: aa _kr _276
# Processing block: aa _krl_232
# Processing block: aa _krl_273
# Processing block: aa _krl_276
# Processing block: aa _krl_298
# Processing block: aa _krs_293
# Processing block: aa _lie_222
# Processing block: aa _lk _234
# Processing block: aa _lk _274
# Processing block: aa _lps_250
# Processing block: aa _lsr_295
# Processing block: aa _mis_246
# Processing block: aa _mis_261
# Processing block: aa _mr _259
# Processing block: aa _mrn_260
# Processing block: aa _mrs_207
# Processing block: aa _n0n_243
# Processing block: aa _nr0_273
# Processing block: aa _pn _274
# Processing block: aa _pr _262
# Processing block: aa _prk_249
# Processing block: aa _prn_239
# Processing block: aa _prn_263
# Processing block: aa _prn_299
# Processing block: aa _prs_285
# Processing block: aa _prt_204
# Processing block: aa _prt_237
# Processing block: aa _prt_245
# Processing block: aa _prt_285
# Processing block: aa _ptr_288
# Processing block: aa _rjn_294
# Processing block: aa _rn _222
# Processing block: aa _rnl_270
# Processing block: aa _rpk_261
# Processing block: aa _rpr_239
# Processing block: aa _rt _294
# Processing block: aa _skt_264
# Processing block: aa _sl _262
# Processing block: aa _sln_268
# Processing block: aa _sr _217
# Processing block: aa _sr _254
# Processing block: aa _stf_255
# Processing block: aa _tft_239
# Processing block: aa _tkl_210
# Processing block: aa _tkl_222
# Processing block: aa _tlr_224
# Processing block: aa _tm _271
# Processing block: aa _tm0_243
# Processing block: aa _tmn_217
# Processing block: aa _tmr_244
# Processing block: aa _tnl_207
# Processing block: aa _tnl_252
# Processing block: aa _tnl_267
# Processing block: aa _tns_245
# Processing block: aa _tns_252
# Processing block: aa _tpr_201
# Processing block: aa _trs_207
# Processing block: aa _trt_267
# Processing block: aa _xlt_203
# Processing block: aa _xn _272
# Processing block: aa _xrl_213
# Processing block: aaj_ptr_244
# Processing block: aaj_ptr_252
# Processing block: aaj_ptr_291
# Processing block: aak_mk _213
# Processing block: aas_l r_217
# Processing block: aas_rnl_263
# Processing block: aas_rnl_275
# Processing block: afl_amn_293
# Processing block: afl_krs_256
# Processing block: afl_mis_265
# Processing block: afl_mis_292
# Processing block: afl_mnt_293
# Processing block: afn_aln_206
# Processing block: afn_aln_276
# Processing block: afn_hf _236
# Processing block: afn_kln_210
# Processing block: afn_klp_241
# Processing block: afn_knk_270
# Processing block: afn_krs_200
# Processing block: afn_lts_215
# Processing block: afn_mn _294
# Processing block: afn_nn _241
# Processing block: afn_nr0_241
# Processing block: afn_nrt_241
# Processing block: afn_por_295
# Processing block: afn_rxl_250
# Processing block: afn_s0 _239
# Processing block: afn_slr_219
# Processing block: afn_stt_245
# Processing block: afn_tn _277
# Processing block: afn_trf_216
# Processing block: afn_trf_243
# Processing block: afn_trf_262
# Processing block: afn_trf_292
# Processing block: afn_xnt_244
# Processing block: afr_kf _211
# Processing block: afr_nxl_235
# Processing block: afr_tn _219
# Processing block: afs_kn _241
# Processing block: aft_ rp_271
# Processing block: ahl_jfr_246
# Processing block: ajn_ sm_210
# Processing block: ajn_flp_278
# Processing block: ajn_sm0_227
# Processing block: ajn_smn_210
# Processing block: ajn_smn_237
# Processing block: ajn_smn_263
# Processing block: ajn_smn_267
# Processing block: ak _spr_211
# Processing block: akk_krt_211
# Processing block: akk_plm_230
# Processing block: akk_wal_221
# Processing block: akl_amn_263
# Processing block: akl_jn _269
# Processing block: akl_m0s_256
# Processing block: akl_mkl_229
# Processing block: akl_mkl_295
# Processing block: akl_rpr_259
# Processing block: akl_tnl_200
# Processing block: akn_anj_253
# Processing block: akn_ark_201
# Processing block: akn_ark_285
# Processing block: akn_asp_213
# Processing block: akn_frt_272
# Processing block: akn_jnf_238
# Processing block: akn_jnf_248
# Processing block: akn_jnf_269
# Processing block: akn_krs_208
# Processing block: akn_new_224
# Processing block: akn_plk_225
# Processing block: akn_rn_283
# Processing block: akn_rpf_288
# Processing block: akn_rpr_259
# Processing block: akn_rpr_274
# Processing block: akn_st _280
# Processing block: akn_tfs_203
# Processing block: akn_tfs_245
# Processing block: akn_tfs_253
# Processing block: akn_tfs_277
# Processing block: akr_k0p_236
# Processing block: akr_pn _274
# Processing block: akr_tmn_217
# Processing block: akr_tr _240
# Processing block: aks_amp_205
# Processing block: aks_hog_225
# Processing block: aks_krn_201
# Processing block: aks_prn_269
# Processing block: aks_prn_291
# Processing block: aks_rl _220
# Processing block: aks_xn _201
# Processing block: akt_nn _297
# Processing block: al _hen_248
# Processing block: al _hrs_279
# Processing block: al _krs_250
# Processing block: al _mrk_264
# Processing block: al _prn_261
# Processing block: al _sn _259
# Processing block: al _sn _290
# Processing block: al _snx_262
# Processing block: al_flr_221
# Processing block: alf_ank_295
# Processing block: alf_ast_224
# Processing block: alf_atn_207
# Processing block: alf_fer_264
# Processing block: alf_fst_218
# Processing block: alf_jn _270
# Processing block: alf_jnf_279
# Processing block: alf_jsf_216
# Processing block: alf_jsf_241
# Processing block: alf_jsf_271
# Processing block: alf_jsf_295
# Processing block: alf_kln_257
# Processing block: alf_ktt_222
# Processing block: alf_lnt_231
# Processing block: alf_ls _240
# Processing block: alf_mkl_223
# Processing block: alf_mks_226
# Processing block: alf_mrk_269
# Processing block: alf_n m_208
# Processing block: alf_nt _210
# Processing block: alf_nt _225
# Processing block: alf_nt _245
# Processing block: alf_nt _259
# Processing block: alf_nt _283
# Processing block: alf_prn_281
# Processing block: alf_prn_295
# Processing block: alf_prt_253
# Processing block: alf_ptr_204
# Processing block: alf_sr _291
# Processing block: alf_ss _202
# Processing block: alf_tms_291
# Processing block: alf_tns_206
# Processing block: alf_trn_238
# Processing block: alj_ls _278
# Processing block: alj_sr _212
# Processing block: alj_sr _281
# Processing block: alj_sr _293
# Processing block: alk_akt_213
# Processing block: alk_alk_244
# Processing block: alk_alk_291
# Processing block: alk_ama_251
# Processing block: alk_ama_266
# Processing block: alk_an0_200
# Processing block: alk_anj_270
# Processing block: alk_ant_203
# Processing block: alk_ar _279
# Processing block: alk_arn_222
# Processing block: alk_ast_297
# Processing block: alk_at _244
# Processing block: alk_atm_263
# Processing block: alk_che_257
# Processing block: alk_jnk_202
# Processing block: alk_jns_202
# Processing block: alk_jns_243
# Processing block: alk_jst_255
# Processing block: alk_kl _241
# Processing block: alk_knt_253
# Processing block: alk_lk _220
# Processing block: alk_lk _245
# Processing block: alk_lk _286
# Processing block: alk_ls _215
# Processing block: alk_ls _229
# Processing block: alk_ls _242
# Processing block: alk_m0 _214
# Processing block: alk_mnk_207
# Processing block: alk_mrs_239
# Processing block: alk_mrs_289
# Processing block: alk_mrt_270
# Processing block: alk_n n_250
# Processing block: alk_nr0_262
# Processing block: alk_pl _214
# Processing block: alk_plm_230
# Processing block: alk_pnt_245
# Processing block: alk_por_208
# Processing block: alk_pr _299
# Processing block: alk_prj_254
# Processing block: alk_prs_247
# Processing block: alk_prt_283
# Processing block: alk_r a_238
# Processing block: alk_rkr_267
# Processing block: alk_rnl_234
# Processing block: alk_rnl_239
# Processing block: alk_rnl_284
# Processing block: alk_rx _243
# Processing block: alk_sm0_292
# Processing block: alk_str_253
# Processing block: alk_sts_241
# Processing block: alk_tmp_271
# Processing block: alk_tn _251
# Processing block: alk_tr _293
# Processing block: alk_xfr_246
# Processing block: alk_xlt_204
# Processing block: alk_xlt_285
# Processing block: alk_xn _289
# Processing block: alk_xn _296
# Processing block: all_akn_202
# Processing block: all_akn_211
# Processing block: all_akn_219
# Processing block: all_amn_286
# Processing block: all_mrk_289
# Processing block: all_skn_224
# Processing block: alm_aft_277
# Processing block: alm_alk_217
# Processing block: alm_alk_267
# Processing block: alm_alm_243
# Processing block: alm_alm_298
# Processing block: alm_als_233
# Processing block: alm_amp_232
# Processing block: alm_an _256
# Processing block: alm_an_229
# Processing block: alm_ank_237
# Processing block: alm_ans_217
# Processing block: alm_ant_219
# Processing block: alm_ant_258
# Processing block: alm_ant_269
# Processing block: alm_ant_272
# Processing block: alm_ar0_245
# Processing block: alm_art_235
# Processing block: alm_ast_250
# Processing block: alm_atm_235
# Processing block: alm_atr_242
# Processing block: alm_ax _203
# Processing block: alm_f0 _207
# Processing block: alm_fns_239
# Processing block: alm_frs_264
# Processing block: alm_fsk_206
# Processing block: alm_fsk_243
# Processing block: alm_fsk_244
# Processing block: alm_fsk_269
# Processing block: alm_fsk_294
# Processing block: alm_h0r_280
# Processing block: alm_hns_215
# Processing block: alm_hns_221
# Processing block: alm_hns_243
# Processing block: alm_hns_262
# Processing block: alm_hns_273
# Processing block: alm_hnt_248
# Processing block: alm_hrs_267
# Processing block: alm_hrt_250
# Processing block: alm_jl _212
# Processing block: alm_jl _229
# Processing block: alm_jl _265
# Processing block: alm_jms_219
# Processing block: alm_jms_238
# Processing block: alm_jms_254
# Processing block: alm_jnf_295
# Processing block: alm_jns_253
# Processing block: alm_jrm_255
# Processing block: alm_k0 _276
# Processing block: alm_kfn_265
# Processing block: alm_kl _211
# Processing block: alm_kl _219
# Processing block: alm_kl _227
# Processing block: alm_kl _245
# Processing block: alm_kln_202
# Processing block: alm_kln_249
# Processing block: alm_kln_251
# Processing block: alm_kln_284
# Processing block: alm_kln_294
# Processing block: alm_kln_295
# Processing block: alm_kmp_215
# Processing block: alm_knk_200
# Processing block: alm_knk_220
# Processing block: alm_krk_272
# Processing block: alm_krk_298
# Processing block: alm_krn_279
# Processing block: alm_krn_287
# Processing block: alm_krp_208
# Processing block: alm_krt_225
# Processing block: alm_kst_277
# Processing block: alm_lrs_242
# Processing block: alm_ls _205
# Processing block: alm_m0 _206
# Processing block: alm_m0 _222
# Processing block: alm_m0 _282
# Processing block: alm_mis_222
# Processing block: alm_mis_272
# Processing block: alm_mk _208
# Processing block: alm_mk _218
# Processing block: alm_mk _237
# Processing block: alm_mkn_203
# Processing block: alm_mkn_225
# Processing block: alm_mkn_250
# Processing block: alm_mkn_266
# Processing block: alm_mkn_276
# Processing block: alm_mkn_277
# Processing block: alm_mkn_279
# Processing block: alm_mkr_258
# Processing block: alm_mkr_259
# Processing block: alm_mkr_292
# Processing block: alm_mkr_298
# Processing block: alm_mr _223
# Processing block: alm_mr _241
# Processing block: alm_mr _274
# Processing block: alm_mr _296
# Processing block: alm_mrf_238
# Processing block: alm_mrk_266
# Processing block: alm_mrk_270
# Processing block: alm_mrk_284
# Processing block: alm_mrk_289
# Processing block: alm_mrn_207
# Processing block: alm_mrn_246
# Processing block: alm_mxl_275
# Processing block: alm_n_276
# Processing block: alm_nk _200
# Processing block: alm_nkl_262
# Processing block: alm_nkn_214
# Processing block: alm_nr0_211
# Processing block: alm_nr0_260
# Processing block: alm_owe_240
# Processing block: alm_pl _272
# Processing block: alm_pnj_282
# Processing block: alm_prn_217
# Processing block: alm_prn_251
# Processing block: alm_prn_265
# Processing block: alm_prn_271
# Processing block: alm_prn_281
# Processing block: alm_prn_291
# Processing block: alm_ps _260
# Processing block: alm_ptr_261
# Processing block: alm_rjs_212
# Processing block: alm_rn _248
# Processing block: alm_rn _265
# Processing block: alm_rn _266
# Processing block: alm_rn _296
# Processing block: alm_rnt_221
# Processing block: alm_rpr_286
# Processing block: alm_rtr_299
# Processing block: alm_s0 _214
# Processing block: alm_skr_213
# Processing block: alm_sm0_257
# Processing block: alm_sn _257
# Processing block: alm_spn_278
# Processing block: alm_stf_263
# Processing block: alm_stf_266
# Processing block: alm_stf_270
# Processing block: alm_stf_275
# Processing block: alm_stf_292
# Processing block: alm_stf_298
# Processing block: alm_str_226
# Processing block: alm_tft_240
# Processing block: alm_tlr_244
# Processing block: alm_tlr_261
# Processing block: alm_tm0_210
# Processing block: alm_tm0_223
# Processing block: alm_tm0_260
# Processing block: alm_tm0_274
# Processing block: alm_tn _265
# Processing block: aln_0 t_297
# Processing block: aln_al _256
# Processing block: aln_alm_240
# Processing block: aln_alm_248
# Processing block: aln_ank_204
# Processing block: aln_ask_262
# Processing block: aln_fln_260
# Processing block: aln_frn_271
# Processing block: aln_jn _265
# Processing block: aln_jnf_252
# Processing block: aln_klr_245
# Processing block: aln_krf_236
# Processing block: aln_ktl_200
# Processing block: aln_lc_265
# Processing block: aln_lk _217
# Processing block: aln_lk _282
# Processing block: aln_lk _295
# Processing block: aln_lk_218
# Processing block: aln_lnt_230
# Processing block: aln_lr _264
# Processing block: aln_lr _267
# Processing block: aln_lr _269
# Processing block: aln_lr _275
# Processing block: aln_lsr_223
# Processing block: aln_lsr_238
# Processing block: aln_lsr_279
# Processing block: aln_lst_210
# Processing block: aln_lst_244
# Processing block: aln_lst_268
# Processing block: aln_lst_275
# Processing block: aln_lst_289
# Processing block: aln_lst_299
# Processing block: aln_mel_240
# Processing block: aln_mlr_202
# Processing block: aln_mxl_202
# Processing block: aln_mxl_224
# Processing block: aln_mxl_258
# Processing block: aln_pk _252
# Processing block: aln_r a_283
# Processing block: aln_rpk_262
# Processing block: aln_sr _240
# Processing block: aln_srn_269
# Processing block: aln_srs_212
# Processing block: aln_stf_240
# Processing block: aln_tft_288
# Processing block: aln_tkl_261
# Processing block: alp_a k_265
# Processing block: alp_krf_265
# Processing block: alp_mkn_219
# Processing block: alp_mkn_227
# Processing block: alp_mkn_244
# Processing block: alp_mkn_261
# Processing block: alp_tfs_271
# Processing block: alr_ant_296
# Processing block: alr_klr_268
# Processing block: alr_mn _218
# Processing block: alr_mn _230
# Processing block: alr_mn _235
# Processing block: alr_mn _292
# Processing block: alr_mn _294
# Processing block: alr_snt_205
# Processing block: als_ mx_212
# Processing block: als_a p_283
# Processing block: als_a t_213
# Processing block: als_a t_255
# Processing block: als_afl_245
# Processing block: als_al _238
# Processing block: als_aln_231
# Processing block: als_als_269
# Processing block: als_an0_257
# Processing block: als_ang_220
# Processing block: als_ant_202
# Processing block: als_ant_207
# Processing block: als_ant_215
# Processing block: als_ant_216
# Processing block: als_ant_222
# Processing block: als_ant_229
# Processing block: als_ant_262
# Processing block: als_ant_277
# Processing block: als_arm_239
# Processing block: als_as _271
# Processing block: als_as _286
# Processing block: als_asn_208
# Processing block: als_ast_242
# Processing block: als_atn_290
# Processing block: als_axl_290
# Processing block: als_axn_231
# Processing block: als_bai_211
# Processing block: als_bai_244
# Processing block: als_bel_226
# Processing block: als_fkt_232
# Processing block: als_flr_288
# Processing block: als_fns_259
# Processing block: als_frk_255
# Processing block: als_frl_289
# Processing block: als_hl _214
# Processing block: als_hl _292
# Processing block: als_hlm_297
# Processing block: als_hns_289
# Processing block: als_hnt_267
# Processing block: als_hpk_231
# Processing block: als_hpk_239
# Processing block: als_ht _205
# Processing block: als_ht _218
# Processing block: als_ht _253
# Processing block: als_iba_215
# Processing block: als_jfr_298
# Processing block: als_jms_208
# Processing block: als_jn _264
# Processing block: als_jnf_248
# Processing block: als_jnf_265
# Processing block: als_jnf_280
# Processing block: als_jnm_245
# Processing block: als_jns_233
# Processing block: als_jns_293
# Processing block: als_jr _219
# Processing block: als_jrj_250
# Processing block: als_jst_260
# Processing block: als_jx _254
# Processing block: als_kfn_233
# Processing block: als_kfn_271
# Processing block: als_kfn_275
# Processing block: als_kln_265
# Processing block: als_klr_299
# Processing block: als_kls_210
# Processing block: als_kls_250
# Processing block: als_krf_209
# Processing block: als_krs_217
# Processing block: als_krs_266
# Processing block: als_krs_271
# Processing block: als_krt_202
# Processing block: als_ksm_294
# Processing block: als_lk _203
# Processing block: als_lk _281
# Processing block: als_lkn_215
# Processing block: als_lnn_270
# Processing block: als_lst_248
# Processing block: als_mis_218
# Processing block: als_mis_267
# Processing block: als_mis_272
# Processing block: als_mkl_200
# Processing block: als_mkl_233
# Processing block: als_mkt_244
# Processing block: als_ml _231
# Processing block: als_mrt_256
# Processing block: als_nks_206
# Processing block: als_nr _202
# Processing block: als_pkn_282
# Processing block: als_pnt_245
# Processing block: als_pr _262
# Processing block: als_prt_205
# Processing block: als_pt _246
# Processing block: als_ptr_203
# Processing block: als_pts_260
# Processing block: als_px _212
# Processing block: als_rjn_286
# Processing block: als_rlf_200
# Processing block: als_rlf_219
# Processing block: als_rlf_227
# Processing block: als_rlf_255
# Processing block: als_rlf_293
# Processing block: als_rnt_280
# Processing block: als_rpr_205
# Processing block: als_rxr_209
# Processing block: als_s0 _217
# Processing block: als_s0 _289
# Processing block: als_sai_209
# Processing block: als_skt_245
# Processing block: als_skt_295
# Processing block: als_skt_299
# Processing block: als_sm0_222
# Processing block: als_sm0_226
# Processing block: als_sm0_229
# Processing block: als_sr _261
# Processing block: als_sr _286
# Processing block: als_tfs_247
# Processing block: als_tft_239
# Processing block: als_tkl_227
# Processing block: als_tlr_253
# Processing block: als_tm0_206
# Processing block: als_tns_211
# Processing block: als_tr _227
# Processing block: als_trn_292
# Processing block: als_tt _289
# Processing block: als_wes_220
# Processing block: als_xn _264
# Processing block: alt_ant_239
# Processing block: alt_eri_213
# Processing block: alt_flr_253
# Processing block: alt_hrn_238
# Processing block: alt_kr _215
# Processing block: alt_krs_254
# Processing block: alt_mln_276
# Processing block: alt_mrs_282
# Processing block: alt_nkl_206
# Processing block: alt_pl _213
# Processing block: alx_alk_298
# Processing block: alx_atm_261
# Processing block: alx_hrt_250
# Processing block: alx_jl _290
# Processing block: alx_jsn_266
# Processing block: alx_kk _261
# Processing block: alx_knk_213
# Processing block: alx_ktm_202
# Processing block: alx_mxl_200
# Processing block: alx_mxl_286
# Processing block: alx_rt _207
# Processing block: alx_s0_226
# Processing block: alx_ss _236
# Processing block: alx_tft_238
# Processing block: alx_tt _244
# Processing block: am _afn_223
# Processing block: am _aln_273
# Processing block: am _als_210
# Processing block: am _ere_237
# Processing block: am _ere_254
# Processing block: am _ere_299
# Processing block: am _flr_200
# Processing block: am _flr_261
# Processing block: am _fls_224
# Processing block: am _frn_243
# Processing block: am _kl _201
# Processing block: am _kl _216
# Processing block: am _kl _240
# Processing block: am _kl _246
# Processing block: am _kn0_217
# Processing block: am _krn_245
# Processing block: am _krn_248
# Processing block: am _krn_257
# Processing block: am _krn_294
# Processing block: am _krs_225
# Processing block: am _krs_280
# Processing block: am _krs_286
# Processing block: am _krs_291
# Processing block: am _ktn_203
# Processing block: am _l f_202
# Processing block: am _l f_250
# Processing block: am _l f_283
# Processing block: am _lkn_255
# Processing block: am _n n_232
# Processing block: am _new_277
# Processing block: am _p f_299
# Processing block: am _sim_231
# Processing block: am _xrl_235
# Processing block: am _xrs_245
# Processing block: amk_kl _212
# Processing block: amk_kl _274
# Processing block: amk_kl _286
# Processing block: aml_ an_283
# Processing block: aml_0rs_210
# Processing block: aml_0rs_232
# Processing block: aml_0rs_239
# Processing block: aml_0rs_277
# Processing block: aml_0rs_289
# Processing block: aml_0rs_290
# Processing block: aml_afn_223
# Processing block: aml_afn_233
# Processing block: aml_afn_256
# Processing block: aml_afn_280
# Processing block: aml_ans_279
# Processing block: aml_ark_226
# Processing block: aml_ash_227
# Processing block: aml_chr_257
# Processing block: aml_chr_276
# Processing block: aml_fns_262
# Processing block: aml_frn_205
# Processing block: aml_frn_228
# Processing block: aml_frn_278
# Processing block: aml_frn_285
# Processing block: aml_hri_224
# Processing block: aml_hub_272
# Processing block: aml_jfr_293
# Processing block: aml_jks_277
# Processing block: aml_jks_290
# Processing block: aml_jns_243
# Processing block: aml_kl _234
# Processing block: aml_kl _256
# Processing block: aml_kl _270
# Processing block: aml_kl _290
# Processing block: aml_krf_221
# Processing block: aml_krp_290
# Processing block: aml_krs_239
# Processing block: aml_mis_225
# Processing block: aml_mis_241
# Processing block: aml_mis_289
# Processing block: aml_mr _288
# Processing block: aml_mrf_270
# Processing block: aml_mrk_248
# Processing block: aml_msn_270
# Processing block: aml_nee_283
# Processing block: aml_new_236
# Processing block: aml_new_244
# Processing block: aml_new_270
# Processing block: aml_npl_214
# Processing block: aml_nr0_209
# Processing block: aml_nr0_273
# Processing block: aml_nr0_293
# Processing block: aml_prs_225
# Processing block: aml_prs_238
# Processing block: aml_prs_263
# Processing block: aml_rs _289
# Processing block: aml_rtn_201
# Processing block: aml_sln_224
# Processing block: aml_sln_237
# Processing block: aml_sln_282
# Processing block: aml_tn _202
# Processing block: aml_tn _277
# Processing block: aml_tn _298
# Processing block: aml_ubb_266
# Processing block: amn_ hr_286
# Processing block: amn_ kr_254
# Processing block: amn_ tn_235
# Processing block: amn_als_205
# Processing block: amn_anj_263
# Processing block: amn_h t_262
# Processing block: amn_hrt_209
# Processing block: amn_hrt_226
# Processing block: amn_hrt_247
# Processing block: amn_hrt_272
# Processing block: amn_hrt_281
# Processing block: amn_jns_204
# Processing block: amn_jns_237
# Processing block: amn_jns_259
# Processing block: amn_jns_297
# Processing block: amn_js _298
# Processing block: amn_jsf_235
# Processing block: amn_jsf_296
# Processing block: amn_km _209
# Processing block: amn_km _288
# Processing block: amn_krl_216
# Processing block: amn_ln _269
# Processing block: amn_mkt_273
# Processing block: amn_mt _274
# Processing block: amn_nks_274
# Processing block: amn_smn_217
# Processing block: amn_sn0_246
# Processing block: amn_sts_238
# Processing block: amn_tkl_222
# Processing block: amn_tks_201
# Processing block: amn_tns_245
# Processing block: amn_tns_284
# Processing block: amn_tpr_233
# Processing block: amn_tpr_287
# Processing block: amn_tpr_298
# Processing block: amn_trn_291
# Processing block: amn_trs_267
# Processing block: amn_x s_252
# Processing block: amp_als_258
# Processing block: amp_jfr_201
# Processing block: amp_jkp_205
# Processing block: amp_jkp_212
# Processing block: amp_jx _209
# Processing block: amp_jx _247
# Processing block: amp_jx _256
# Processing block: amp_jx _264
# Processing block: amp_lps_222
# Processing block: amp_prs_256
# Processing block: amp_prt_226
# Processing block: amp_prt_288
# Processing block: amp_sim_206
# Processing block: amr_ kn_201
# Processing block: amr_alm_268
# Processing block: amr_apr_243
# Processing block: amr_jnf_245
# Processing block: amr_jnf_265
# Processing block: amr_jnf_282
# Processing block: amr_klt_293
# Processing block: amr_lnk_246
# Processing block: amr_slr_262
# Processing block: amr_spr_294
# Processing block: amr_trn_200
# Processing block: ams_sim_210
# Processing block: amt_atk_281
# Processing block: amt_krn_221
# Processing block: amt_prs_256
# Processing block: amt_wes_281
# Processing block: an _ mr_269
# Processing block: an _ pr_289
# Processing block: an _alm_231
# Processing block: an _art_228
# Processing block: an _ast_207
# Processing block: an _ast_256
# Processing block: an _ast_262
# Processing block: an _ast_266
# Processing block: an _ast_295
# Processing block: an _hmn_219
# Processing block: an _hns_270
# Processing block: an _hpr_201
# Processing block: an _hpr_269
# Processing block: an _hpr_278
# Processing block: an _hpr_299
# Processing block: an _jn _256
# Processing block: an _jn _265
# Processing block: an _jn0_238
# Processing block: an _jn0_277
# Processing block: an _klt_204
# Processing block: an _klt_243
# Processing block: an _knt_210
# Processing block: an _krn_237
# Processing block: an _lps_293
# Processing block: an _ls _251
# Processing block: an _ltr_288
# Processing block: an _mel_217
# Processing block: an _mez_242
# Processing block: an _mis_285
# Processing block: an _mk _205
# Processing block: an _mk _280
# Processing block: an _mkl_264
# Processing block: an _ms _212
# Processing block: an _ms _285
# Processing block: an _ms _293
# Processing block: an _msk_241
# Processing block: an _mts_285
# Processing block: an _prt_206
# Processing block: an _prt_258
# Processing block: an _prt_281
# Processing block: an _rln_287
# Processing block: an _rnl_298
# Processing block: an _rsl_204
# Processing block: an _rsl_220
# Processing block: an _rsl_259
# Processing block: an _skt_219
# Processing block: an _skt_256
# Processing block: an _sm0_230
# Processing block: an _sm0_291
# Processing block: an _snf_248
# Processing block: an _stm_253
# Processing block: an _tkr_221
# Processing block: an _tmn_260
# Processing block: an _tn _257
# Processing block: an _tns_292
# Processing block: an _trn_250
# Processing block: an0_0rs_294
# Processing block: an0_a a_267
# Processing block: an0_alm_297
# Processing block: an0_als_212
# Processing block: an0_als_266
# Processing block: an0_als_292
# Processing block: an0_an0_215
# Processing block: an0_atm_247
# Processing block: an0_atm_269
# Processing block: an0_fk _291
# Processing block: an0_fkf_289
# Processing block: an0_flr_239
# Processing block: an0_flr_257
# Processing block: an0_flr_290
# Processing block: an0_fns_268
# Processing block: an0_jnf_281
# Processing block: an0_jns_258
# Processing block: an0_jst_265
# Processing block: an0_kln_209
# Processing block: an0_kln_245
# Processing block: an0_kr _219
# Processing block: an0_krf_214
# Processing block: an0_krf_270
# Processing block: an0_krf_279
# Processing block: an0_krs_248
# Processing block: an0_krs_271
# Processing block: an0_krs_278
# Processing block: an0_lak_217
# Processing block: an0_lk _201
# Processing block: an0_lk _218
# Processing block: an0_lk_293
# Processing block: an0_lr _280
# Processing block: an0_mis_246
# Processing block: an0_mlr_200
# Processing block: an0_mlr_207
# Processing block: an0_mlr_225
# Processing block: an0_mlr_243
# Processing block: an0_mlr_296
# Processing block: an0_mr _291
# Processing block: an0_nxl_278
# Processing block: an0_prp_238
# Processing block: an0_prs_294
# Processing block: an0_ptl_202
# Processing block: an0_rtr_216
# Processing block: an0_sks_232
# Processing block: an0_skt_296
# Processing block: an0_tft_235
# Processing block: an0_tmp_232
# Processing block: an0_trs_204
# Processing block: an0_trs_299
# Processing block: an_flj_269
# Processing block: an_jsf_254
# Processing block: an_mis_216
# Processing block: an_skt_285
# Processing block: an_snk_284
# Processing block: anf_kr _297
# Processing block: anf_prs_224
# Processing block: anf_prs_230
# Processing block: anf_prs_282
# Processing block: anj_ hl_233
# Processing block: anj_ hl_298
# Processing block: anj_ hr_207
# Processing block: anj_ sk_284
# Processing block: anj_0mp_292
# Processing block: anj_alm_250
# Processing block: anj_apr_236
# Processing block: anj_jsn_215
# Processing block: anj_jsn_237
# Processing block: anj_jsn_262
# Processing block: anj_kt _251
# Processing block: anj_kt _273
# Processing block: anj_ls _275
# Processing block: anj_mr _207
# Processing block: anj_nor_229
# Processing block: anj_pns_264
# Processing block: anj_prk_216
# Processing block: anj_prt_289
# Processing block: anj_rjn_234
# Processing block: anj_rjn_284
# Processing block: anj_rpk_261
# Processing block: anj_shr_233
# Processing block: anj_skt_221
# Processing block: anj_skt_236
# Processing block: anj_skt_241
# Processing block: anj_stf_243
# Processing block: anj_stf_273
# Processing block: anj_tft_218
# Processing block: anj_tmp_292
# Processing block: anj_tp0_245
# Processing block: anj_ts _236
# Processing block: anj_ts _284
# Processing block: anj_ts _295
# Processing block: anj_xl _209
# Processing block: ank_ mk_289
# Processing block: ank_alk_268
# Processing block: ank_am _292
# Processing block: ank_ant_238
# Processing block: ank_arn_245
# Processing block: ank_ast_205
# Processing block: ank_axl_266
# Processing block: ank_axl_293
# Processing block: ank_con_235
# Processing block: ank_f a_251
# Processing block: ank_f a_274
# Processing block: ank_f a_294
# Processing block: ank_fls_202
# Processing block: ank_hhs_265
# Processing block: ank_hrn_255
# Processing block: ank_jn _240
# Processing block: ank_jns_254
# Processing block: ank_jsk_247
# Processing block: ank_jsm_215
# Processing block: ank_jsn_221
# Processing block: ank_k0 _265
# Processing block: ank_kin_253
# Processing block: ank_kmp_264
# Processing block: ank_kms_232
# Processing block: ank_kms_266
# Processing block: ank_kms_276
# Processing block: ank_kms_291
# Processing block: ank_krs_273
# Processing block: ank_lk _216
# Processing block: ank_lpj_282
# Processing block: ank_lrn_204
# Processing block: ank_ls _232
# Processing block: ank_ls _299
# Processing block: ank_mkl_210
# Processing block: ank_mr _264
# Processing block: ank_mxl_223
# Processing block: ank_nt _240
# Processing block: ank_och_297
# Processing block: ank_pft_233
# Processing block: ank_prn_273
# Processing block: ank_rpr_271
# Processing block: ank_rpr_273
# Processing block: ank_rt _212
# Processing block: ank_sfj_213
# Processing block: ank_smn_272
# Processing block: ank_stf_280
# Processing block: ank_tft_254
# Processing block: ank_tm0_226
# Processing block: ank_tm0_228
# Processing block: ank_tm0_247
# Processing block: ank_tm0_250
# Processing block: ank_tm0_295
# Processing block: ank_tmr_288
# Processing block: ank_tmr_298
# Processing block: ank_tn _208
# Processing block: ank_tn _234
# Processing block: anl_ ss_226
# Processing block: anl_klr_287
# Processing block: anl_krn_298
# Processing block: anl_r_222
# Processing block: anm_jn_273
# Processing block: anm_skt_220
# Processing block: anm_tfn_249
# Processing block: ann_krt_262
# Processing block: ann_mkn_257
# Processing block: ann_mln_237
# Processing block: ann_rl _212
# Processing block: anr_alk_220
# Processing block: anr_hns_285
# Processing block: anr_krf_221
# Processing block: anr_krl_263
# Processing block: anr_krs_297
# Processing block: anr_kt _296
# Processing block: anr_lk _223
# Processing block: ans_ ml_222
# Processing block: ans_ark_254
# Processing block: ans_fl_204
# Processing block: ans_jns_298
# Processing block: ans_mar_249
# Processing block: ans_tfs_223
# Processing block: ant_ pr_249
# Processing block: ant_ sl_285
# Processing block: ant_(th_207
# Processing block: ant_(th_233
# Processing block: ant_alk_211
# Processing block: ant_alk_268
# Processing block: ant_aln_207
# Processing block: ant_aln_276
# Processing block: ant_aln_283
# Processing block: ant_als_247
# Processing block: ant_als_261
# Processing block: ant_ans_244
# Processing block: ant_ans_282
# Processing block: ant_ant_235
# Processing block: ant_ant_273
# Processing block: ant_ant_289
# Processing block: ant_ant_293
# Processing block: ant_ast_259
# Processing block: ant_at _215
# Processing block: ant_at _283
# Processing block: ant_atm_282
# Processing block: ant_ats_275
# Processing block: ant_axl_228
# Processing block: ant_fks_204
# Processing block: ant_fr _264
# Processing block: ant_frn_292
# Processing block: ant_frn_298
# Processing block: ant_frs_288
# Processing block: ant_frt_258
# Processing block: ant_hn _285
# Processing block: ant_hrp_204
# Processing block: ant_hrt_221
# Processing block: ant_jnf_251
# Processing block: ant_jns_209
# Processing block: ant_jsf_241
# Processing block: ant_jsk_213
# Processing block: ant_jx _246
# Processing block: ant_k0r_228
# Processing block: ant_kfn_245
# Processing block: ant_kln_294
# Processing block: ant_kmp_211
# Processing block: ant_kmp_289
# Processing block: ant_kmp_296
# Processing block: ant_kn _261
# Processing block: ant_krs_211
# Processing block: ant_krs_216
# Processing block: ant_krs_225
# Processing block: ant_krs_286
# Processing block: ant_krs_298
# Processing block: ant_ks _274
# Processing block: ant_l p_292
# Processing block: ant_lkn_212
# Processing block: ant_lln_231
# Processing block: ant_lln_299
# Processing block: ant_lmp_266
# Processing block: ant_lnt_249
# Processing block: ant_lrn_235
# Processing block: ant_mis_212
# Processing block: ant_mis_223
# Processing block: ant_mk _277
# Processing block: ant_mr _206
# Processing block: ant_mrn_220
# Processing block: ant_ms _226
# Processing block: ant_n r_204
# Processing block: ant_n r_247
# Processing block: ant_n r_256
# Processing block: ant_n r_264
# Processing block: ant_n r_287
# Processing block: ant_nat_264
# Processing block: ant_nr0_285
# Processing block: ant_ntx_204
# Processing block: ant_pat_297
# Processing block: ant_pn _274
# Processing block: ant_prk_204
# Processing block: ant_prk_210
# Processing block: ant_prk_227
# Processing block: ant_prk_249
# Processing block: ant_prk_283
# Processing block: ant_prt_227
# Processing block: ant_prt_296
# Processing block: ant_ptr_251
# Processing block: ant_ran_259
# Processing block: ant_rfr_223
# Processing block: ant_rs _273
# Processing block: ant_sml_224
# Processing block: ant_sml_254
# Processing block: ant_sou_248
# Processing block: ant_ter_219
# Processing block: ant_tft_235
# Processing block: ant_tmr_279
# Processing block: ant_tmr_283
# Processing block: ant_tms_298
# Processing block: ant_trr_209
# Processing block: ant_trs_293
# Processing block: ant_tt _236
# Processing block: ant_xrt_295
# Processing block: anx_xrt_212
# Processing block: apk_jrt_251
# Processing block: apk_kr _289
# Processing block: apk_ksn_219
# Processing block: apk_mic_224
# Processing block: apl_jms_269
# Processing block: apn_ tr_262
# Processing block: apn_aml_212
# Processing block: apn_aml_237
# Processing block: apn_aml_245
# Processing block: apn_aml_255
# Processing block: apn_aml_267
# Processing block: apn_hns_270
# Processing block: apn_kim_281
# Processing block: apn_s0_256
# Processing block: app_ant_213
# Processing block: app_hlt_242
# Processing block: app_krp_268
# Processing block: app_skt_234
# Processing block: app_tnl_260
# Processing block: apr_als_260
# Processing block: apr_als_265
# Processing block: apr_amn_224
# Processing block: apr_ant_215
# Processing block: apr_ask_213
# Processing block: apr_hrn_206
# Processing block: apr_krs_227
# Processing block: apr_lsn_258
# Processing block: apr_ptr_250
# Processing block: apr_ptr_263
# Processing block: apr_ptr_277
# Processing block: apr_ptr_280
# Processing block: apr_ptr_283
# Processing block: apr_r_215
# Processing block: apr_rpr_212
# Processing block: apr_rpr_214
# Processing block: apr_rpr_226
# Processing block: apr_rpr_232
# Processing block: apr_rpr_262
# Processing block: aps_kps_234
# Processing block: aps_mxl_281
# Processing block: aps_nns_268
# Processing block: aps_rkr_247
# Processing block: apt_ast_265
# Processing block: apt_hs _298
# Processing block: ar _ak _273
# Processing block: ar _kfm_231
# Processing block: ar _prt_293
# Processing block: ar _ptn_248
# Processing block: ar _rs _239
# Processing block: ar _rs _260
# Processing block: ar _trn_285
# Processing block: ar0_ l _299
# Processing block: ar0_apr_255
# Processing block: ar0_kln_269
# Processing block: ar0_krl_220
# Processing block: ar0_krt_209
# Processing block: ar0_l f_299
# Processing block: ar0_mrk_216
# Processing block: ar0_mrk_218
# Processing block: ar0_mrk_249
# Processing block: ar0_prk_238
# Processing block: arj_jms_255
# Processing block: arj_jms_267
# Processing block: arj_jms_277
# Processing block: arj_jms_278
# Processing block: ark_ fl_253
# Processing block: ark_ rn_223
# Processing block: ark_afn_241
# Processing block: ark_ant_259
# Processing block: ark_apr_234
# Processing block: ark_ast_286
# Processing block: ark_fkt_292
# Processing block: ark_jms_264
# Processing block: ark_jn _270
# Processing block: ark_jns_209
# Processing block: ark_jns_214
# Processing block: ark_jns_222
# Processing block: ark_k0r_288
# Processing block: ark_ln _243
# Processing block: ark_ln _260
# Processing block: ark_ln _266
# Processing block: ark_mk _267
# Processing block: ark_pit_241
# Processing block: ark_por_223
# Processing block: ark_prn_209
# Processing block: ark_prn_221
# Processing block: ark_prn_280
# Processing block: ark_prt_220
# Processing block: ark_prt_264
# Processing block: ark_prt_267
# Processing block: ark_pxp_294
# Processing block: ark_rl _223
# Processing block: ark_rl _247
# Processing block: ark_rmr_217
# Processing block: ark_rn _203
# Processing block: ark_rn _275
# Processing block: ark_rn _293
# Processing block: ark_tlr_284
# Processing block: ark_tns_259
# Processing block: ark_xmt_297
# Processing block: arl_kfn_299
# Processing block: arl_kl _236
# Processing block: arl_mnt_288
# Processing block: arm_lks_208
# Processing block: arm_lks_212
# Processing block: arm_lks_251
# Processing block: arm_lts_211
# Processing block: arm_tnl_254
# Processing block: arn_  n_247
# Processing block: arn_als_238
# Processing block: arn_an _233
# Processing block: arn_an _241
# Processing block: arn_an0_276
# Processing block: arn_anj_292
# Processing block: arn_arn_282
# Processing block: arn_ast_209
# Processing block: arn_ath_289
# Processing block: arn_chr_231
# Processing block: arn_fk _281
# Processing block: arn_flr_238
# Processing block: arn_fst_217
# Processing block: arn_fst_258
# Processing block: arn_gut_267
# Processing block: arn_har_243
# Processing block: arn_hjs_243
# Processing block: arn_hl _245
# Processing block: arn_hn _248
# Processing block: arn_hnt_266
# Processing block: arn_jn _253
# Processing block: arn_jn _293
# Processing block: arn_jsk_247
# Processing block: arn_kll_248
# Processing block: arn_kt_214
# Processing block: arn_lk _212
# Processing block: arn_mis_228
# Processing block: arn_mk _233
# Processing block: arn_mkl_241
# Processing block: arn_mkl_296
# Processing block: arn_mr _288
# Processing block: arn_nn _271
# Processing block: arn_pk _222
# Processing block: arn_pn _275
# Processing block: arn_por_265
# Processing block: arn_prk_205
# Processing block: arn_prs_237
# Processing block: arn_prt_283
# Processing block: arn_prt_289
# Processing block: arn_ptr_216
# Processing block: arn_r p_221
# Processing block: arn_r p_244
# Processing block: arn_rn _235
# Processing block: arn_rt _262
# Processing block: arn_san_292
# Processing block: arn_snx_226
# Processing block: arn_snx_227
# Processing block: arn_snx_261
# Processing block: arn_snx_296
# Processing block: arn_tfs_215
# Processing block: arn_tmn_203
# Processing block: arn_tms_284
# Processing block: arn_tns_268
# Processing block: arn_xnk_231
# Processing block: arp_kl _251
# Processing block: arp_prn_291
# Processing block: arr_krl_212
# Processing block: ars_an _275
# Processing block: ars_klt_222
# Processing block: ars_knt_219
# Processing block: ars_knt_230
# Processing block: ars_knt_233
# Processing block: ars_krs_215
# Processing block: ars_nr0_245
# Processing block: ars_stn_293
# Processing block: ars_t n_293
# Processing block: ars_tn _219
# Processing block: ars_tn _226
# Processing block: ars_tn _275
# Processing block: ars_tn _282
# Processing block: ars_tns_219
# Processing block: art_ fr_294
# Processing block: art_ l _299
# Processing block: art_ nk_217
# Processing block: art_afr_206
# Processing block: art_afr_231
# Processing block: art_afr_246
# Processing block: art_als_271
# Processing block: art_als_274
# Processing block: art_flr_276
# Processing block: art_hfm_229
# Processing block: art_kks_297
# Processing block: art_krk_231
# Processing block: art_krl_219
# Processing block: art_krl_232
# Processing block: art_krl_298
# Processing block: art_krs_211
# Processing block: art_krs_247
# Processing block: art_krs_287
# Processing block: art_lnk_211
# Processing block: art_ls _247
# Processing block: art_mis_214
# Processing block: art_mrk_270
# Processing block: art_nor_258
# Processing block: art_par_218
# Processing block: art_ptr_258
# Processing block: art_rn _293
# Processing block: art_rs _250
# Processing block: art_sr _231
# Processing block: art_tfn_268
# Processing block: art_tnl_245
# Processing block: as _als_221
# Processing block: as _prt_209
# Processing block: as _skr_218
# Processing block: as _sr _216
# Processing block: as_mrt_207
# Processing block: ask__243
# Processing block: ask__258
# Processing block: ask__260
# Processing block: ask_lnt_210
# Processing block: ask_nr _293
# Processing block: ask_nr0_243
# Processing block: ask_nr0_288
# Processing block: ask_prt_222
# Processing block: ask_srs_222
# Processing block: ask_tn _224
# Processing block: asl_a k_231
# Processing block: asl_a k_279
# Processing block: asl_a k_281
# Processing block: asl_a k_299
# Processing block: asl_krs_276
# Processing block: asn_nr0_236
# Processing block: asn_s0 _208
# Processing block: asp_hn _221
# Processing block: asp_hn _233
# Processing block: asp_hn_298
# Processing block: asp_jms_217
# Processing block: asp_krs_268
# Processing block: asp_mr _288
# Processing block: asp_ptr_244
# Processing block: asp_sps_257
# Processing block: ast_ sp_200
# Processing block: ast_alm_236
# Processing block: ast_arn_267
# Processing block: ast_ast_266
# Processing block: ast_fk _204
# Processing block: ast_fst_214
# Processing block: ast_fst_239
# Processing block: ast_fst_240
# Processing block: ast_fst_298
# Processing block: ast_jn _244
# Processing block: ast_jnf_200
# Processing block: ast_l k_230
# Processing block: ast_lar_261
# Processing block: ast_mrf_211
# Processing block: ast_n r_242
# Processing block: ast_n. _239
# Processing block: ast_oro_277
# Processing block: ast_pnk_219
# Processing block: ast_trs_226
# Processing block: at _frt_226
# Processing block: at _hrn_256
# Processing block: at _jns_223
# Processing block: at _jst_273
# Processing block: at _krf_296
# Processing block: at _krs_220
# Processing block: at _krt_291
# Processing block: at _lns_202
# Processing block: at _lrn_200
# Processing block: at _mrs_213
# Processing block: at _mrs_267
# Processing block: at _mrs_271
# Processing block: at _nn _297
# Processing block: at _nr0_297
# Processing block: at _pr _208
# Processing block: at _pr _263
# Processing block: at _pr _284
# Processing block: at _prn_263
# Processing block: at _prt_207
# Processing block: at _prt_224
# Processing block: at _ptr_273
# Processing block: at _rn _258
# Processing block: at _rpr_216
# Processing block: at _sls_204
# Processing block: at _snt_210
# Processing block: at _spr_208
# Processing block: at _ssn_274
# Processing block: at _ssn_282
# Processing block: at _ssn_285
# Processing block: at _str_266
# Processing block: at _tft_230
# Processing block: at _tft_262
# Processing block: at _tft_279
# Processing block: at _tft_280
# Processing block: at _tlr_206
# Processing block: at _tlr_291
# Processing block: at_ ar_267
# Processing block: at_ ar_296
# Processing block: at_mkl_233
# Processing block: atf_prk_230
# Processing block: atk_ kk_278
# Processing block: atk_alj_215
# Processing block: atk_alm_223
# Processing block: atk_ats_286
# Processing block: atk_hrp_237
# Processing block: atk_kk _214
# Processing block: atk_kk _237
# Processing block: atk_kk _259
# Processing block: atk_m0 _281
# Processing block: atk_mnt_293
# Processing block: atk_n k_282
# Processing block: atk_prt_219
# Processing block: atk_snx_280
# Processing block: atk_stf_252
# Processing block: atk_tft_235
# Processing block: atk_tms_279
# Processing block: atl_jrm_239
# Processing block: atm_als_203
# Processing block: atm_als_208
# Processing block: atm_als_228
# Processing block: atm_ark_274
# Processing block: atm_ast_277
# Processing block: atm_fj _204
# Processing block: atm_flp_236
# Processing block: atm_hls_295
# Processing block: atm_hns_262
# Processing block: atm_jnk_218
# Processing block: atm_jnk_277
# Processing block: atm_jos_291
# Processing block: atm_jsf_211
# Processing block: atm_jsf_235
# Processing block: atm_jsf_236
# Processing block: atm_jsf_275
# Processing block: atm_jsn_267
# Processing block: atm_klr_236
# Processing block: atm_kns_208
# Processing block: atm_kns_249
# Processing block: atm_ksm_283
# Processing block: atm_kst_243
# Processing block: atm_lk _258
# Processing block: atm_ln _284
# Processing block: atm_mis_214
# Processing block: atm_mis_243
# Processing block: atm_mkl_235
# Processing block: atm_mkl_269
# ...
# Processing block: trn_rs _268
# Processing block: trn_rs _282
# Processing block: trn_tfn_289
# Processing block: trp_ls _226
# Processing block: trr_alk_214
# Processing block: trr_alk_254
# Processing block: trr_hrs_233
# Processing block: trr_jn _283
# Processing block: trr_lsf_294
# Processing block: trr_mis_277
# Processing block: trr_mt _274
# Processing block: trr_rpr_219
# Processing block: trr_rpr_225
# Processing block: trr_xls_260
# Processing block: trs_a n_234
# Processing block: trs_a n_235
# Processing block: trs_alm_239
# Processing block: trs_aml_216
# Processing block: trs_aml_237
# Processing block: trs_aml_242
# Processing block: trs_aml_264
# Processing block: trs_aml_297
# Processing block: trs_an0_200
# Processing block: trs_anj_288
# Processing block: trs_ant_237
# Processing block: trs_ant_260
# Processing block: trs_ant_270
# Processing block: trs_ast_210
# Processing block: trs_bry_262
# Processing block: trs_hs _235
# Processing block: trs_jkl_202
# Processing block: trs_jms_271
# Processing block: trs_kmp_290
# Processing block: trs_kns_238
# Processing block: trs_kpr_208
# Processing block: trs_krs_271
# Processing block: trs_krt_231
# Processing block: trs_mkl_271
# Processing block: trs_mln_223
# Processing block: trs_p0 _267
# Processing block: trs_prp_227
# Processing block: trs_rs _263
# Processing block: trs_rs _277
# Processing block: trs_s0 _276
# Processing block: trs_tnl_252
# Processing block: trs_trl_202
# Processing block: trs_trs_237
# Processing block: trs_trs_271
# Processing block: trs_xnt_278
# Processing block: trt_aks_220
# Processing block: trt_frn_272
# Processing block: trt_h k_215
# Processing block: trt_jn0_238
# Processing block: trt_kks_228
# Processing block: trt_mkn_265
# Processing block: trt_mxl_217
# Processing block: trt_nt _254
# Processing block: trt_prn_215
# Processing block: trt_snx_253
# Processing block: ts _smr_296
# Processing block: ts _tnl_256
# Processing block: ts_mxl_245
# Processing block: tsf_fks_279
# Processing block: tsf_js _253
# Processing block: tsf_lsp_299
# Processing block: tsf_mic_246
# Processing block: tsf_pnt_200
# Processing block: tsm_smp_212
# Processing block: tsn_ast_273
# Processing block: tsn_hrt_255
# Processing block: tsn_rjr_226
# Processing block: tsr_new_282
# Processing block: tss_aa _206
# Processing block: tss_nfr_205
# Processing block: tss_nt _236
# Processing block: tss_nt _294
# Processing block: tss_prn_214
# Processing block: tss_ptr_212
# Processing block: tss_ptr_285
# Processing block: tss_tm _218
# Processing block: tst_jmn_236
# Processing block: tst_jmn_252
# Processing block: tst_jmn_269
# Processing block: tst_jmn_275
# Processing block: tst_jmn_295
# Processing block: tst_jsf_293
# Processing block: tst_kpl_283
# Processing block: tst_pts_243
# Processing block: tst_pts_249
# Processing block: tst_pts_285
# Processing block: tt _ ss_284
# Processing block: tt _a n_227
# Processing block: tt _a n_245
# Processing block: tt _a n_250
# Processing block: tt _a n_285
# Processing block: tt _a n_296
# Processing block: tt _alf_225
# Processing block: tt _alk_201
# Processing block: tt _alk_242
# Processing block: tt _alm_224
# Processing block: tt _als_248
# Processing block: tt _als_287
# Processing block: tt _amn_202
# Processing block: tt _amn_288
# Processing block: tt _anj_249
# Processing block: tt _anj_257
# Processing block: tt _anj_272
# Processing block: tt _anj_285
# Processing block: tt _anj_291
# Processing block: tt _art_248
# Processing block: tt _ast_202
# Processing block: tt _ast_231
# Processing block: tt _ast_288
# Processing block: tt _ast_299
# Processing block: tt _atr_209
# Processing block: tt _axl_235
# Processing block: tt _axn_212
# Processing block: tt _flk_236
# Processing block: tt _flk_250
# Processing block: tt _flk_253
# Processing block: tt _flk_282
# Processing block: tt _fln_213
# Processing block: tt _flr_257
# Processing block: tt _frn_205
# Processing block: tt _frn_247
# Processing block: tt _frn_268
# Processing block: tt _frn_277
# Processing block: tt _har_250
# Processing block: tt _hl _240
# Processing block: tt _hl _275
# Processing block: tt _hrn_228
# Processing block: tt _jms_203
# Processing block: tt _kl _295
# Processing block: tt _klk_283
# Processing block: tt _kls_269
# Processing block: tt _kns_216
# Processing block: tt _kns_290
# Processing block: tt _kr _255
# Processing block: tt _krl_263
# Processing block: tt _krl_286
# Processing block: tt _krn_257
# Processing block: tt _krn_266
# Processing block: tt _krn_298
# Processing block: tt _krs_232
# Processing block: tt _krs_239
# Processing block: tt _krs_263
# Processing block: tt _krs_274
# Processing block: tt _krs_281
# Processing block: tt _krt_234
# Processing block: tt _ksr_293
# Processing block: tt _l l_257
# Processing block: tt _lnt_206
# Processing block: tt _lnt_212
# Processing block: tt _lr _222
# Processing block: tt _ls _226
# Processing block: tt _lsl_228
# Processing block: tt _m0s_266
# Processing block: tt _mis_235
# Processing block: tt _mkl_210
# Processing block: tt _mkl_228
# Processing block: tt _mkl_268
# Processing block: tt _mln_285
# Processing block: tt _mlr_244
# Processing block: tt _mls_221
# Processing block: tt _mnt_293
# Processing block: tt _mrk_257
# Processing block: tt _mrk_283
# Processing block: tt _n n_245
# Processing block: tt _nf0_235
# Processing block: tt _nkl_226
# Processing block: tt _nkl_242
# Processing block: tt _nr0_238
# Processing block: tt _nr0_242
# Processing block: tt _nr0_245
# Processing block: tt _pl _254
# Processing block: tt _pnt_273
# Processing block: tt _prj_226
# Processing block: tt _prn_258
# Processing block: tt _prp_234
# Processing block: tt _prs_209
# Processing block: tt _prs_221
# Processing block: tt _prs_285
# Processing block: tt _ptl_226
# Processing block: tt _rmn_216
# Processing block: tt _rpk_209
# Processing block: tt _rpr_222
# Processing block: tt _rpr_297
# Processing block: tt _rt _211
# Processing block: tt _sm0_250
# Processing block: tt _smp_273
# Processing block: tt _snt_299
# Processing block: tt _sr _247
# Processing block: tt _sr _263
# Processing block: tt _sr _277
# Processing block: tt _stf_208
# Processing block: tt _stf_231
# Processing block: tt _stf_291
# Processing block: tt _stn_288
# Processing block: tt _t a_294
# Processing block: tt _tfn_269
# Processing block: tt _tms_229
# Processing block: tt _tn _240
# Processing block: tt _tns_251
# Processing block: tt _trf_265
# Processing block: tt _trl_208
# Processing block: tt _trn_200
# Processing block: tt _trs_219
# Processing block: tt _trs_265
# Processing block: tt _trs_272
# Processing block: tt _trs_288
# Processing block: tt _tt _231
# Processing block: tt _xlt_240
# Processing block: tt _xlt_262
# Processing block: ttf_alm_211
# Processing block: ttf_frn_209
# Processing block: ttf_kk _264
# Processing block: ttf_kks_232
# Processing block: ttf_ks _291
# Processing block: ttf_l f_240
# Processing block: ttf_lk _290
# Processing block: ttf_sol_213
# Processing block: ttf_sr _226
# Processing block: ttj_a k_282
# Processing block: ttj_a k_294
# Processing block: ttj_alm_221
# Processing block: ttj_flt_222
# Processing block: ttj_klp_203
# Processing block: ttk_aml_297
# Processing block: ttk_an _238
# Processing block: ttk_ark_210
# Processing block: ttk_bro_274
# Processing block: ttk_flp_210
# Processing block: ttk_flp_273
# Processing block: ttk_jrt_242
# Processing block: ttk_kl _204
# Processing block: ttk_kln_247
# Processing block: ttk_krl_249
# Processing block: ttk_lnr_234
# Processing block: ttk_mlr_211
# Processing block: ttk_mxl_244
# Processing block: ttk_nns_243
# Processing block: ttk_nns_283
# Processing block: ttk_nns_295
# Processing block: ttk_p0n_270
# Processing block: ttk_prk_270
# Processing block: ttk_pts_274
# Processing block: ttk_rn _251
# Processing block: ttk_sm0_206
# Processing block: ttk_sn _251
# Processing block: ttk_ssn_266
# Processing block: ttk_tft_283
# Processing block: ttk_tks_282
# Processing block: ttk_xrl_289
# Processing block: ttm_akl_280
# Processing block: ttm_ast_298
# Processing block: ttm_jst_249
# Processing block: ttm_n t_261
# Processing block: ttm_pp _216
# Processing block: ttm_rmn_294
# Processing block: ttm_rpn_278
# Processing block: ttn_jsm_209
# Processing block: ttn_kf _236
# Processing block: ttn_kns_210
# Processing block: ttn_lsf_231
# Processing block: ttn_rpr_277
# Processing block: ttp_ tf_201
# Processing block: ttp_a a_287
# Processing block: ttp_ark_266
# Processing block: ttp_krf_286
# Processing block: ttp_lk _231
# Processing block: ttp_lps_219
# Processing block: ttp_prn_220
# Processing block: ttp_rkf_234
# Processing block: ttp_sr _261
# Processing block: ttp_st_209
# Processing block: ttp_st_223
# Processing block: ttp_st_253
# Processing block: ttp_st_281
# Processing block: ttp_tf _201
# Processing block: ttp_tm _214
# Processing block: ttp_tm0_254
# Processing block: ttr_ak _265
# Processing block: ttr_kmp_299
# Processing block: ttr_mkl_221
# Processing block: ttr_ml _293
# Processing block: ttr_xlt_296
# Processing block: tts_ans_282
# Processing block: tts_ant_237
# Processing block: tts_ant_292
# Processing block: tts_f0 _250
# Processing block: tts_kfn_253
# Processing block: tts_krk_208
# Processing block: tts_krn_213
# Processing block: tts_lsl_286
# Processing block: tts_mis_208
# Processing block: tts_prj_268
# Processing block: tts_rnj_293
# Processing block: tts_rsl_230
# Processing block: tts_rsl_235
# Processing block: tts_rt _283
# Processing block: tts_rt_266
# Processing block: tts_spn_227
# Processing block: tts_str_224
# Processing block: tts_tn _207
# Processing block: ttt_ mk_206
# Processing block: ttt_ sm_296
# Processing block: ttt_ tf_278
# Processing block: ttt__289
# Processing block: ttt_als_220
# Processing block: ttt_als_228
# Processing block: ttt_als_248
# Processing block: ttt_als_268
# Processing block: ttt_apr_284
# Processing block: ttt_axl_214
# Processing block: ttt_flp_282
# Processing block: ttt_jms_218
# Processing block: ttt_kfn_235
# Processing block: ttt_kpl_282
# Processing block: ttt_kr _201
# Processing block: ttt_ls _245
# Processing block: ttt_luc_249
# Processing block: ttt_prn_257
# Processing block: ttt_prt_223
# Processing block: ttt_prt_226
# Processing block: ttt_ptr_274
# Processing block: ttt_s0 _238
# Processing block: ttt_trn_272
# Processing block: x l_tlr_245
# Processing block: x p_prn_211
# Processing block: x_krs_274
# Processing block: x_mis_215
# Processing block: x_mlr_217
# Processing block: x_t s_295
# Processing block: x_tmp_209
# Processing block: xf _nt _273
# Processing block: xfr_alm_244
# Processing block: xfr_bro_249
# Processing block: xfr_knn_258
# Processing block: xfr_krs_264
# Processing block: xfr_m0 _253
# Processing block: xfr_nt _204
# Processing block: xfr_nt _230
# Processing block: xfr_nt _244
# Processing block: xfr_tft_285
# Processing block: xfr_tn _217
# Processing block: xfs_alk_209
# Processing block: xfs_ars_216
# Processing block: xfs_ast_206
# Processing block: xfs_jn _230
# Processing block: xfs_jns_230
# Processing block: xfs_mrt_210
# Processing block: xfs_new_219
# Processing block: xfs_prn_227
# Processing block: xfs_rsl_260
# Processing block: xfs_sm0_211
# Processing block: xfs_sur_223
# Processing block: xkf_prn_205
# Processing block: xl _alm_219
# Processing block: xl _alm_241
# Processing block: xl _alm_292
# Processing block: xl _ast_216
# Processing block: xl _fr _223
# Processing block: xl _kmf_263
# Processing block: xl _kmp_246
# Processing block: xl _kmp_258
# Processing block: xl _tpt_224
# Processing block: xlk_atk_251
# Processing block: xls_jnf_270
# Processing block: xls_jnf_280
# Processing block: xls_jnf_281
# Processing block: xls_jnf_282
# Processing block: xlt_ _211
# Processing block: xlt_alm_241
# Processing block: xlt_axl_273
# Processing block: xlt_dan_267
# Processing block: xlt_nxl_263
# Processing block: xlt_r0 _218
# Processing block: xmp_mrk_273
# Processing block: xmp_prt_290
# Processing block: xmt_ kr_292
# Processing block: xmt_frn_246
# Processing block: xmt_frt_209
# Processing block: xmt_rtn_282
# Processing block: xmt_str_289
# Processing block: xmt_tfs_201
# Processing block: xmt_tm0_288
# Processing block: xn _ js_210
# Processing block: xn _ js_217
# Processing block: xn _ js_224
# Processing block: xn _an0_243
# Processing block: xn _cay_251
# Processing block: xn _mj _221
# Processing block: xn _ray_208
# Processing block: xn _sm0_240
# Processing block: xnk_slm_252
# Processing block: xnn_a p_260
# Processing block: xnn_a x_239
# Processing block: xnn_a x_299
# Processing block: xnn_ast_224
# Processing block: xnn_jn _230
# Processing block: xnn_jnk_273
# Processing block: xnn_jsn_223
# Processing block: xnn_jsn_227
# Processing block: xnn_jsn_282
# Processing block: xnn_jsn_293
# Processing block: xnn_klt_203
# Processing block: xnn_knt_223
# Processing block: xnn_krt_262
# Processing block: xnn_ktl_287
# Processing block: xnn_mrt_232
# Processing block: xnn_pat_208
# Processing block: xnn_prk_234
# Processing block: xnn_prk_238
# Processing block: xnn_prk_242
# Processing block: xnn_prt_226
# Processing block: xnn_ptr_208
# Processing block: xnn_rpn_218
# Processing block: xnn_rpn_231
# Processing block: xnn_rpn_283
# Processing block: xnn_rpr_230
# Processing block: xnn_smn_200
# Processing block: xnn_smn_218
# Processing block: xnn_smn_272
# Processing block: xnn_smn_299
# Processing block: xnn_snt_291
# Processing block: xnn_x k_266
# Processing block: xnn_xnf_290
# Processing block: xnp_krs_276
# Processing block: xnt_a n_268
# Processing block: xnt_mls_205
# Processing block: xnt_mrk_235
# Processing block: xnt_mrk_281
# Processing block: xnt_prt_248
# Processing block: xnt_tlr_261
# Processing block: xpm_jsf_299
# Processing block: xpm_rpk_289
# Processing block: xpr_prn_232
# Processing block: xpr_prn_263
# Processing block: xpr_prn_269
# Processing block: xpr_prn_295
# Processing block: xr _als_212
# Processing block: xr _als_225
# Processing block: xr _als_239
# Processing block: xr _als_240
# Processing block: xr _als_273
# Processing block: xr _als_281
# Processing block: xr _als_282
# Processing block: xr _ant_216
# Processing block: xr _hrt_287
# Processing block: xr _jn _250
# Processing block: xr _jn _271
# Processing block: xr _prt_266
# Processing block: xr _tls_268
# Processing block: xr_als_219
# Processing block: xrl_aa _281
# Processing block: xrl_ark_290
# Processing block: xrl_ast_208
# Processing block: xrl_ast_269
# Processing block: xrl_ast_270
# Processing block: xrl_ast_274
# Processing block: xrl_atm_217
# Processing block: xrl_atm_225
# Processing block: xrl_atm_226
# Processing block: xrl_atm_236
# Processing block: xrl_atm_271
# Processing block: xrl_dan_283
# Processing block: xrl_jn _210
# Processing block: xrl_jn _261
# Processing block: xrl_js_222
# Processing block: xrl_jt _253
# Processing block: xrl_jt _291
# Processing block: xrl_jt _296
# Processing block: xrl_kn0_205
# Processing block: xrl_knr_212
# Processing block: xrl_kr _201
# Processing block: xrl_lk _238
# Processing block: xrl_lk_238
# Processing block: xrl_ls _212
# Processing block: xrl_mos_243
# Processing block: xrl_mrk_213
# Processing block: xrl_nln_291
# Processing block: xrl_prs_205
# Processing block: xrl_prt_257
# Processing block: xrl_ptr_215
# Processing block: xrl_ptr_223
# Processing block: xrl_rxr_220
# Processing block: xrl_rxr_282
# Processing block: xrl_rxr_289
# Processing block: xrl_sm _213
# Processing block: xrl_sml_238
# Processing block: xrl_tft_265
# Processing block: xrl_tft_278
# Processing block: xrl_xlt_230
# Processing block: xrl_xlt_235
# Processing block: xrl_xlt_245
# Processing block: xrl_xlt_270
# Processing block: xrl_xlt_292
# Processing block: xrm_mls_262
# Processing block: xrm_rt _273
# Processing block: xrm_tnk_273
# Processing block: xrn_jn0_224
# Processing block: xrn_prn_217
# Processing block: xrp_als_268
# Processing block: xrp_rt _253
# Processing block: xrp_wri_279
# Processing block: xrt_akn_241
# Processing block: xrt_alm_207
# Processing block: xrt_flp_243
# Processing block: xrt_jns_203
# Processing block: xrt_jns_212
# Processing block: xrt_jsk_201
# Processing block: xrt_khn_264
# Processing block: xrt_l p_295
# Processing block: xrt_rt _203
# Processing block: xrt_rt _278
# Processing block: xrx_jns_203
# Processing block: xs _wil_273
# Processing block: xt _hmp_291
# Processing block: xt _jx _244
# Processing block: xt _rjn_216
# Processing block: xt _rjn_242
# Processing block: xt _rjn_258
# Processing block: xt _rjn_281
# Processing block: xt _rjn_283
# Processing block: xt _srr_250
# Processing block: xt _xmp_213
# Processing block: xt _xmp_232
# Processing block: xt _xmp_270
# Processing block: xt _xmp_279
# <Axes: xlabel='external_id'>
# Text(0.5, 1.0, 'Distribución de Clusters')
# Text(0.5, 0, 'Cluster ID')
# Text(0, 0.5, 'Tamaño del Cluster')

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import pdist, squareform

def calculate_similarity(df, column):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(df[column].fillna(''))
    cosine_sim = cosine_similarity(tfidf_matrix)
    return pd.DataFrame(cosine_sim, index=df.index, columns=df.index)

# Similaridad en nombres y direcciones
name_similarity = calculate_similarity(merged_df, 'parsed_name')
address_similarity = calculate_similarity(merged_df, 'parsed_address_street_name')
# Calculate similarity for numerical variable 'transaction_amount'
account_similarity = pd.DataFrame(
    1 - squareform(pdist(merged_df[['account_id']], metric='euclidean')),
    index=merged_df.index,
    columns=merged_df.index
)

# %%
def create_block_key(value, prefix_length=5):
    if pd.isna(value):  # Maneja valores faltantes
        return 'MISSING'
    return value[:prefix_length].lower()

# Aplica el bloqueo en la columna deseada
merged_df['block'] = merged_df['parsed_name'].apply(create_block_key, prefix_length=3)

def create_combined_block(row):
    # Combina prefijos de varias columnas
    name_key = create_block_key(row['parsed_name'], prefix_length=3)
    address_key = create_block_key(row['parsed_address_street_name'], prefix_length=3)
    # account_key = create_block_key(str(row['account_id']), prefix_length=3)  
    return f"{name_key}_{address_key}"

merged_df['block'] = merged_df.apply(create_combined_block, axis=1)

blocks = merged_df.groupby('block')

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# # Función para calcular similitud con TF-IDF
# def calculate_similarity(df, column):
#     vectorizer = TfidfVectorizer()
#     filled_column = df[column].fillna('MISSING')  # Rellena missings temporalmente
#     tfidf_matrix = vectorizer.fit_transform(filled_column)
#     cosine_sim = cosine_similarity(tfidf_matrix)
    
#     # Opcional: Penaliza similitud para valores originalmente faltantes
#     missing_mask = df[column].isna().values
#     cosine_sim[missing_mask, :] = 0
#     cosine_sim[:, missing_mask] = 0
    
#     return cosine_sim


# # Función de blocking
# def create_block_key(value, prefix_length=5):
#     if pd.isna(value):  # Maneja valores faltantes
#         return 'MISSING'
#     return value[:prefix_length].lower()

# # Aplica el bloqueo en la columna deseada
# merged_df['block'] = merged_df['parsed_name'].apply(create_block_key, prefix_length=3)

# def create_combined_block(row):
#     # Combina prefijos de varias columnas
#     name_key = create_block_key(row['parsed_name'], prefix_length=3)
#     address_key = create_block_key(row['parsed_address_street_name'], prefix_length=3)
#     return f"{name_key}_{address_key}"

# merged_df['block'] = merged_df.apply(create_combined_block, axis=1)
# blocks = merged_df.groupby('block')


# # Procesar cada bloque


# merged_df['parsed_address_street_name'].fillna(
# merged_df['parsed_address_city'].fillna('MISSING'), inplace=True
# )

results = []

for block_name, block_data in blocks:
    print(f"Processing block: {block_name}")
    
    if len(block_data) < 2:
        # Si el bloque tiene solo un registro, lo marcamos como un singleton
        block_data['external_id'] = range(len(results), len(results) + len(block_data))
        results.append(block_data)
        continue

    # Similaridad para nombres y direcciones

    name_similarity = calculate_similarity(block_data, 'parsed_name')
    #address_similarity = calculate_similarity(block_data, 'parsed_address_street_name')
    #print(address_similarity)
    
    # Combinar las similitudes
    similarity_matrix = name_similarity #+ 0.3 * address_similarity
    
    # Asegurarse de que los valores de la matriz de similitud estén en el rango [0, 1]
    similarity_matrix = np.clip(similarity_matrix, 0, 1)
    
    # Convertimos la matriz de similitud en distancias
    distance_matrix = 1 - similarity_matrix
    
    # Aplicamos DBSCAN
    db = DBSCAN(eps=0.3, min_samples=2, metric='precomputed')
    clusters = db.fit_predict(distance_matrix)
    
    # Asignamos clusters como external_id
    block_data['external_id'] = clusters + len(results)  # Evita conflictos entre bloques
    results.append(block_data)

# Combinar los resultados de todos los bloques
final_df = pd.concat(results, ignore_index=True)
# Out:
# Processing block:  0r_rtr_299
# Processing block:  ak_rt _212
# Processing block:  al_jsk_215
# Processing block:  al_nn _217
# Processing block:  al_tlr_297
# Processing block:  am_n n_203
# Processing block:  ar_ant_239
# Processing block:  as_ as_211
# Processing block:  as_ as_290
# Processing block:  at_hnt_209
# Processing block:  fr_ fr_288
# Processing block:  hk_krs_202
# Processing block:  hk_krs_245
# Processing block:  hk_lrn_254
# Processing block:  hk_mrk_211
# Processing block:  hk_p0 _262
# Processing block:  hk_tf _271
# Processing block:  hr_krs_222
# Processing block:  hr_ls _294
# Processing block:  hr_m0 _204
# Processing block:  hr_rtr_251
# Processing block:  jn_a_203
# Processing block:  jn_lrn_229
# Processing block:  jn_plk_286
# Processing block:  jn_rsl_258
# Processing block:  jn_tms_284
# Processing block:  jn_tnl_267
# Processing block:  k0_jks_260
# Processing block:  kn_rpk_234
# Processing block:  kp_tmp_299
# Processing block:  kr_knk_200
# Processing block:  kr_prn_200
# Processing block:  kr_prn_265
# Processing block:  lr_nkl_247
# Processing block:  m0_ kr_203
# Processing block:  m0_ m0_238
# Processing block:  m0_ m0_270
# Processing block:  mk_ kr_265
# Processing block:  mk_jn _261
# Processing block:  mk_krs_217
# Processing block:  mk_n l_287
# Processing block:  mk_tn _227
# Processing block:  mn_ ts_207
# Processing block:  mn_ts _256
# Processing block:  mt_jks_252
# Processing block:  nl_tan_202
# Processing block:  p_mxl_204
# Processing block:  rp_rxl_226
# Processing block:  rp_rxl_236
# Processing block:  rp_rxl_269
# Processing block:  sm_atm_284
# Processing block:  sm_prn_281
# Processing block:  tf_kpl_292
# Processing block:  tk_jms_222
# Processing block:  tk_prn_237
# Processing block:  tk_prn_239
# Processing block:  tn_ant_247
# Processing block: 0js_at _223
# Processing block: 0ms_lsl_240
# Processing block: 0ms_tkm_254
# Processing block: 0r _krs_264
# Processing block: 0rn_hol_214
# Processing block: 0rn_hrn_259
# Processing block: 0rn_jxl_263
# Processing block: 0rn_mlt_203
# Processing block: 0rn_rsm_276
# Processing block: 0rs_har_225
# Processing block: 0rs_har_238
# Processing block: 0rs_har_262
# Processing block: 0rs_hrs_295
# Processing block: 0rs_jns_230
# Processing block: 0rs_krs_200
# Processing block: 0rs_mis_252
# Processing block: 0tr_ant_294
# Processing block: 0tr_kns_207
# Processing block: 0tr_mis_282
# Processing block: 0tr_mkl_240
# Processing block: 0tr_spr_217
# Processing block: 0tr_sts_207
# Processing block: a h_k p_264
# Processing block: a l_jnf_269
# Processing block: a l_tft_245
# Processing block: a l_tft_254
# Processing block: a n_pns_274
# Processing block: a p_alm_270
# Processing block: a p_peo_273
# Processing block: a p_stf_212
# Processing block: a p_stf_218
# Processing block: a s_flr_225
# Processing block: a t_krn_206
# Processing block: a t_rt _241
# Processing block: a0l_frn_268
# Processing block: aa _ sm_253
# Processing block: aa _aa _230
# Processing block: aa _aa _232
# Processing block: aa _aa _273
# Processing block: aa _afl_251
# Processing block: aa _afn_234
# Processing block: aa _afn_241
# Processing block: aa _afn_285
# Processing block: aa _afr_214
# Processing block: aa _akl_205
# Processing block: aa _akl_215
# Processing block: aa _als_268
# Processing block: aa _am _233
# Processing block: aa _an _231
# Processing block: aa _an _258
# Processing block: aa _an _266
# Processing block: aa _an _296
# Processing block: aa _an _298
# Processing block: aa _ank_205
# Processing block: aa _at _210
# Processing block: aa _ats_223
# Processing block: aa _coo_233
# Processing block: aa _fle_264
# Processing block: aa _flr_286
# Processing block: aa _frn_218
# Processing block: aa _frn_293
# Processing block: aa _hnt_238
# Processing block: aa _hpk_285
# Processing block: aa _hpk_293
# Processing block: aa _hpr_255
# Processing block: aa _hrn_222
# Processing block: aa _jkp_237
# Processing block: aa _jm _224
# Processing block: aa _jn _213
# Processing block: aa _jn0_238
# Processing block: aa _jnf_290
# Processing block: aa _jnm_245
# Processing block: aa _jns_204
# Processing block: aa _jns_207
# Processing block: aa _jns_214
# Processing block: aa _jns_226
# Processing block: aa _jns_232
# Processing block: aa _jns_249
# Processing block: aa _jns_271
# Processing block: aa _jns_295
# Processing block: aa _jrm_263
# Processing block: aa _jsn_207
# Processing block: aa _jx _285
# Processing block: aa _k0_208
# Processing block: aa _kl _223
# Processing block: aa _klm_250
# Processing block: aa _klt_244
# Processing block: aa _klt_258
# Processing block: aa _kn0_215
# Processing block: aa _kps_221
# Processing block: aa _kr _276
# Processing block: aa _krl_232
# Processing block: aa _krl_273
# Processing block: aa _krl_276
# Processing block: aa _krl_298
# Processing block: aa _krs_293
# Processing block: aa _lie_222
# Processing block: aa _lk _234
# Processing block: aa _lk _274
# Processing block: aa _lps_250
# Processing block: aa _lsr_295
# Processing block: aa _mis_246
# Processing block: aa _mis_261
# Processing block: aa _mr _259
# Processing block: aa _mrn_260
# Processing block: aa _mrs_207
# Processing block: aa _n0n_243
# Processing block: aa _nr0_273
# Processing block: aa _pn _274
# Processing block: aa _pr _262
# Processing block: aa _prk_249
# Processing block: aa _prn_239
# Processing block: aa _prn_263
# Processing block: aa _prn_299
# Processing block: aa _prs_285
# Processing block: aa _prt_204
# Processing block: aa _prt_237
# Processing block: aa _prt_245
# Processing block: aa _prt_285
# Processing block: aa _ptr_288
# Processing block: aa _rjn_294
# Processing block: aa _rn _222
# Processing block: aa _rnl_270
# Processing block: aa _rpk_261
# Processing block: aa _rpr_239
# Processing block: aa _rt _294
# Processing block: aa _skt_264
# Processing block: aa _sl _262
# Processing block: aa _sln_268
# Processing block: aa _sr _217
# Processing block: aa _sr _254
# Processing block: aa _stf_255
# Processing block: aa _tft_239
# Processing block: aa _tkl_210
# Processing block: aa _tkl_222
# Processing block: aa _tlr_224
# Processing block: aa _tm _271
# Processing block: aa _tm0_243
# Processing block: aa _tmn_217
# Processing block: aa _tmr_244
# Processing block: aa _tnl_207
# Processing block: aa _tnl_252
# Processing block: aa _tnl_267
# Processing block: aa _tns_245
# Processing block: aa _tns_252
# Processing block: aa _tpr_201
# Processing block: aa _trs_207
# Processing block: aa _trt_267
# Processing block: aa _xlt_203
# Processing block: aa _xn _272
# Processing block: aa _xrl_213
# Processing block: aaj_ptr_244
# Processing block: aaj_ptr_252
# Processing block: aaj_ptr_291
# Processing block: aak_mk _213
# Processing block: aas_l r_217
# Processing block: aas_rnl_263
# Processing block: aas_rnl_275
# Processing block: afl_amn_293
# Processing block: afl_krs_256
# Processing block: afl_mis_265
# Processing block: afl_mis_292
# Processing block: afl_mnt_293
# Processing block: afn_aln_206
# Processing block: afn_aln_276
# Processing block: afn_hf _236
# Processing block: afn_kln_210
# Processing block: afn_klp_241
# Processing block: afn_knk_270
# Processing block: afn_krs_200
# Processing block: afn_lts_215
# Processing block: afn_mn _294
# Processing block: afn_nn _241
# Processing block: afn_nr0_241
# Processing block: afn_nrt_241
# Processing block: afn_por_295
# Processing block: afn_rxl_250
# Processing block: afn_s0 _239
# Processing block: afn_slr_219
# Processing block: afn_stt_245
# Processing block: afn_tn _277
# Processing block: afn_trf_216
# Processing block: afn_trf_243
# Processing block: afn_trf_262
# Processing block: afn_trf_292
# Processing block: afn_xnt_244
# Processing block: afr_kf _211
# Processing block: afr_nxl_235
# Processing block: afr_tn _219
# Processing block: afs_kn _241
# Processing block: aft_ rp_271
# Processing block: ahl_jfr_246
# Processing block: ajn_ sm_210
# Processing block: ajn_flp_278
# Processing block: ajn_sm0_227
# Processing block: ajn_smn_210
# Processing block: ajn_smn_237
# Processing block: ajn_smn_263
# Processing block: ajn_smn_267
# Processing block: ak _spr_211
# Processing block: akk_krt_211
# Processing block: akk_plm_230
# Processing block: akk_wal_221
# Processing block: akl_amn_263
# Processing block: akl_jn _269
# Processing block: akl_m0s_256
# Processing block: akl_mkl_229
# Processing block: akl_mkl_295
# Processing block: akl_rpr_259
# Processing block: akl_tnl_200
# Processing block: akn_anj_253
# Processing block: akn_ark_201
# Processing block: akn_ark_285
# Processing block: akn_asp_213
# Processing block: akn_frt_272
# Processing block: akn_jnf_238
# Processing block: akn_jnf_248
# Processing block: akn_jnf_269
# Processing block: akn_krs_208
# Processing block: akn_new_224
# Processing block: akn_plk_225
# Processing block: akn_rn_283
# Processing block: akn_rpf_288
# Processing block: akn_rpr_259
# Processing block: akn_rpr_274
# Processing block: akn_st _280
# Processing block: akn_tfs_203
# Processing block: akn_tfs_245
# Processing block: akn_tfs_253
# Processing block: akn_tfs_277
# Processing block: akr_k0p_236
# Processing block: akr_pn _274
# Processing block: akr_tmn_217
# Processing block: akr_tr _240
# Processing block: aks_amp_205
# Processing block: aks_hog_225
# Processing block: aks_krn_201
# Processing block: aks_prn_269
# Processing block: aks_prn_291
# Processing block: aks_rl _220
# Processing block: aks_xn _201
# Processing block: akt_nn _297
# Processing block: al _hen_248
# Processing block: al _hrs_279
# Processing block: al _krs_250
# Processing block: al _mrk_264
# Processing block: al _prn_261
# Processing block: al _sn _259
# Processing block: al _sn _290
# Processing block: al _snx_262
# Processing block: al_flr_221
# Processing block: alf_ank_295
# Processing block: alf_ast_224
# Processing block: alf_atn_207
# Processing block: alf_fer_264
# Processing block: alf_fst_218
# Processing block: alf_jn _270
# Processing block: alf_jnf_279
# Processing block: alf_jsf_216
# Processing block: alf_jsf_241
# Processing block: alf_jsf_271
# Processing block: alf_jsf_295
# Processing block: alf_kln_257
# Processing block: alf_ktt_222
# Processing block: alf_lnt_231
# Processing block: alf_ls _240
# Processing block: alf_mkl_223
# Processing block: alf_mks_226
# Processing block: alf_mrk_269
# Processing block: alf_n m_208
# Processing block: alf_nt _210
# Processing block: alf_nt _225
# Processing block: alf_nt _245
# Processing block: alf_nt _259
# Processing block: alf_nt _283
# Processing block: alf_prn_281
# Processing block: alf_prn_295
# Processing block: alf_prt_253
# Processing block: alf_ptr_204
# Processing block: alf_sr _291
# Processing block: alf_ss _202
# Processing block: alf_tms_291
# Processing block: alf_tns_206
# Processing block: alf_trn_238
# Processing block: alj_ls _278
# Processing block: alj_sr _212
# Processing block: alj_sr _281
# Processing block: alj_sr _293
# Processing block: alk_akt_213
# Processing block: alk_alk_244
# Processing block: alk_alk_291
# Processing block: alk_ama_251
# Processing block: alk_ama_266
# Processing block: alk_an0_200
# Processing block: alk_anj_270
# Processing block: alk_ant_203
# Processing block: alk_ar _279
# Processing block: alk_arn_222
# Processing block: alk_ast_297
# Processing block: alk_at _244
# Processing block: alk_atm_263
# Processing block: alk_che_257
# Processing block: alk_jnk_202
# Processing block: alk_jns_202
# Processing block: alk_jns_243
# Processing block: alk_jst_255
# Processing block: alk_kl _241
# Processing block: alk_knt_253
# Processing block: alk_lk _220
# Processing block: alk_lk _245
# Processing block: alk_lk _286
# Processing block: alk_ls _215
# Processing block: alk_ls _229
# Processing block: alk_ls _242
# Processing block: alk_m0 _214
# Processing block: alk_mnk_207
# Processing block: alk_mrs_239
# Processing block: alk_mrs_289
# Processing block: alk_mrt_270
# Processing block: alk_n n_250
# Processing block: alk_nr0_262
# Processing block: alk_pl _214
# Processing block: alk_plm_230
# Processing block: alk_pnt_245
# Processing block: alk_por_208
# Processing block: alk_pr _299
# Processing block: alk_prj_254
# Processing block: alk_prs_247
# Processing block: alk_prt_283
# Processing block: alk_r a_238
# Processing block: alk_rkr_267
# Processing block: alk_rnl_234
# Processing block: alk_rnl_239
# Processing block: alk_rnl_284
# Processing block: alk_rx _243
# Processing block: alk_sm0_292
# Processing block: alk_str_253
# Processing block: alk_sts_241
# Processing block: alk_tmp_271
# Processing block: alk_tn _251
# Processing block: alk_tr _293
# Processing block: alk_xfr_246
# Processing block: alk_xlt_204
# Processing block: alk_xlt_285
# Processing block: alk_xn _289
# Processing block: alk_xn _296
# Processing block: all_akn_202
# Processing block: all_akn_211
# Processing block: all_akn_219
# Processing block: all_amn_286
# Processing block: all_mrk_289
# Processing block: all_skn_224
# Processing block: alm_aft_277
# Processing block: alm_alk_217
# Processing block: alm_alk_267
# Processing block: alm_alm_243
# Processing block: alm_alm_298
# Processing block: alm_als_233
# Processing block: alm_amp_232
# Processing block: alm_an _256
# Processing block: alm_an_229
# Processing block: alm_ank_237
# Processing block: alm_ans_217
# Processing block: alm_ant_219
# Processing block: alm_ant_258
# Processing block: alm_ant_269
# Processing block: alm_ant_272
# Processing block: alm_ar0_245
# Processing block: alm_art_235
# Processing block: alm_ast_250
# Processing block: alm_atm_235
# Processing block: alm_atr_242
# Processing block: alm_ax _203
# Processing block: alm_f0 _207
# Processing block: alm_fns_239
# Processing block: alm_frs_264
# Processing block: alm_fsk_206
# Processing block: alm_fsk_243
# Processing block: alm_fsk_244
# Processing block: alm_fsk_269
# Processing block: alm_fsk_294
# Processing block: alm_h0r_280
# Processing block: alm_hns_215
# Processing block: alm_hns_221
# Processing block: alm_hns_243
# Processing block: alm_hns_262
# Processing block: alm_hns_273
# Processing block: alm_hnt_248
# Processing block: alm_hrs_267
# Processing block: alm_hrt_250
# Processing block: alm_jl _212
# Processing block: alm_jl _229
# Processing block: alm_jl _265
# Processing block: alm_jms_219
# Processing block: alm_jms_238
# Processing block: alm_jms_254
# Processing block: alm_jnf_295
# Processing block: alm_jns_253
# Processing block: alm_jrm_255
# Processing block: alm_k0 _276
# Processing block: alm_kfn_265
# Processing block: alm_kl _211
# Processing block: alm_kl _219
# Processing block: alm_kl _227
# Processing block: alm_kl _245
# Processing block: alm_kln_202
# Processing block: alm_kln_249
# Processing block: alm_kln_251
# Processing block: alm_kln_284
# Processing block: alm_kln_294
# Processing block: alm_kln_295
# Processing block: alm_kmp_215
# Processing block: alm_knk_200
# Processing block: alm_knk_220
# Processing block: alm_krk_272
# Processing block: alm_krk_298
# Processing block: alm_krn_279
# Processing block: alm_krn_287
# Processing block: alm_krp_208
# Processing block: alm_krt_225
# Processing block: alm_kst_277
# Processing block: alm_lrs_242
# Processing block: alm_ls _205
# Processing block: alm_m0 _206
# Processing block: alm_m0 _222
# Processing block: alm_m0 _282
# Processing block: alm_mis_222
# Processing block: alm_mis_272
# Processing block: alm_mk _208
# Processing block: alm_mk _218
# Processing block: alm_mk _237
# Processing block: alm_mkn_203
# Processing block: alm_mkn_225
# Processing block: alm_mkn_250
# Processing block: alm_mkn_266
# Processing block: alm_mkn_276
# Processing block: alm_mkn_277
# Processing block: alm_mkn_279
# Processing block: alm_mkr_258
# Processing block: alm_mkr_259
# Processing block: alm_mkr_292
# Processing block: alm_mkr_298
# Processing block: alm_mr _223
# Processing block: alm_mr _241
# Processing block: alm_mr _274
# Processing block: alm_mr _296
# Processing block: alm_mrf_238
# Processing block: alm_mrk_266
# Processing block: alm_mrk_270
# Processing block: alm_mrk_284
# Processing block: alm_mrk_289
# Processing block: alm_mrn_207
# Processing block: alm_mrn_246
# Processing block: alm_mxl_275
# Processing block: alm_n_276
# Processing block: alm_nk _200
# Processing block: alm_nkl_262
# Processing block: alm_nkn_214
# Processing block: alm_nr0_211
# Processing block: alm_nr0_260
# Processing block: alm_owe_240
# Processing block: alm_pl _272
# Processing block: alm_pnj_282
# Processing block: alm_prn_217
# Processing block: alm_prn_251
# Processing block: alm_prn_265
# Processing block: alm_prn_271
# Processing block: alm_prn_281
# Processing block: alm_prn_291
# Processing block: alm_ps _260
# Processing block: alm_ptr_261
# Processing block: alm_rjs_212
# Processing block: alm_rn _248
# Processing block: alm_rn _265
# Processing block: alm_rn _266
# Processing block: alm_rn _296
# Processing block: alm_rnt_221
# Processing block: alm_rpr_286
# Processing block: alm_rtr_299
# Processing block: alm_s0 _214
# Processing block: alm_skr_213
# Processing block: alm_sm0_257
# Processing block: alm_sn _257
# Processing block: alm_spn_278
# Processing block: alm_stf_263
# Processing block: alm_stf_266
# Processing block: alm_stf_270
# Processing block: alm_stf_275
# Processing block: alm_stf_292
# Processing block: alm_stf_298
# Processing block: alm_str_226
# Processing block: alm_tft_240
# Processing block: alm_tlr_244
# Processing block: alm_tlr_261
# Processing block: alm_tm0_210
# Processing block: alm_tm0_223
# Processing block: alm_tm0_260
# Processing block: alm_tm0_274
# Processing block: alm_tn _265
# Processing block: aln_0 t_297
# Processing block: aln_al _256
# Processing block: aln_alm_240
# Processing block: aln_alm_248
# Processing block: aln_ank_204
# Processing block: aln_ask_262
# Processing block: aln_fln_260
# Processing block: aln_frn_271
# Processing block: aln_jn _265
# Processing block: aln_jnf_252
# Processing block: aln_klr_245
# Processing block: aln_krf_236
# Processing block: aln_ktl_200
# Processing block: aln_lc_265
# Processing block: aln_lk _217
# Processing block: aln_lk _282
# Processing block: aln_lk _295
# Processing block: aln_lk_218
# Processing block: aln_lnt_230
# Processing block: aln_lr _264
# Processing block: aln_lr _267
# Processing block: aln_lr _269
# Processing block: aln_lr _275
# Processing block: aln_lsr_223
# Processing block: aln_lsr_238
# Processing block: aln_lsr_279
# Processing block: aln_lst_210
# Processing block: aln_lst_244
# Processing block: aln_lst_268
# Processing block: aln_lst_275
# Processing block: aln_lst_289
# Processing block: aln_lst_299
# Processing block: aln_mel_240
# Processing block: aln_mlr_202
# Processing block: aln_mxl_202
# Processing block: aln_mxl_224
# Processing block: aln_mxl_258
# Processing block: aln_pk _252
# Processing block: aln_r a_283
# Processing block: aln_rpk_262
# Processing block: aln_sr _240
# Processing block: aln_srn_269
# Processing block: aln_srs_212
# Processing block: aln_stf_240
# Processing block: aln_tft_288
# Processing block: aln_tkl_261
# Processing block: alp_a k_265
# Processing block: alp_krf_265
# Processing block: alp_mkn_219
# Processing block: alp_mkn_227
# Processing block: alp_mkn_244
# Processing block: alp_mkn_261
# Processing block: alp_tfs_271
# Processing block: alr_ant_296
# Processing block: alr_klr_268
# Processing block: alr_mn _218
# Processing block: alr_mn _230
# Processing block: alr_mn _235
# Processing block: alr_mn _292
# Processing block: alr_mn _294
# Processing block: alr_snt_205
# Processing block: als_ mx_212
# Processing block: als_a p_283
# Processing block: als_a t_213
# Processing block: als_a t_255
# Processing block: als_afl_245
# Processing block: als_al _238
# Processing block: als_aln_231
# Processing block: als_als_269
# Processing block: als_an0_257
# Processing block: als_ang_220
# Processing block: als_ant_202
# Processing block: als_ant_207
# Processing block: als_ant_215
# Processing block: als_ant_216
# Processing block: als_ant_222
# Processing block: als_ant_229
# Processing block: als_ant_262
# Processing block: als_ant_277
# Processing block: als_arm_239
# Processing block: als_as _271
# Processing block: als_as _286
# Processing block: als_asn_208
# Processing block: als_ast_242
# Processing block: als_atn_290
# Processing block: als_axl_290
# Processing block: als_axn_231
# Processing block: als_bai_211
# Processing block: als_bai_244
# Processing block: als_bel_226
# Processing block: als_fkt_232
# Processing block: als_flr_288
# Processing block: als_fns_259
# Processing block: als_frk_255
# Processing block: als_frl_289
# Processing block: als_hl _214
# Processing block: als_hl _292
# Processing block: als_hlm_297
# Processing block: als_hns_289
# Processing block: als_hnt_267
# Processing block: als_hpk_231
# Processing block: als_hpk_239
# Processing block: als_ht _205
# Processing block: als_ht _218
# Processing block: als_ht _253
# Processing block: als_iba_215
# Processing block: als_jfr_298
# Processing block: als_jms_208
# Processing block: als_jn _264
# Processing block: als_jnf_248
# Processing block: als_jnf_265
# Processing block: als_jnf_280
# Processing block: als_jnm_245
# Processing block: als_jns_233
# Processing block: als_jns_293
# Processing block: als_jr _219
# Processing block: als_jrj_250
# Processing block: als_jst_260
# Processing block: als_jx _254
# Processing block: als_kfn_233
# Processing block: als_kfn_271
# Processing block: als_kfn_275
# Processing block: als_kln_265
# Processing block: als_klr_299
# Processing block: als_kls_210
# Processing block: als_kls_250
# Processing block: als_krf_209
# Processing block: als_krs_217
# Processing block: als_krs_266
# Processing block: als_krs_271
# Processing block: als_krt_202
# Processing block: als_ksm_294
# Processing block: als_lk _203
# Processing block: als_lk _281
# Processing block: als_lkn_215
# Processing block: als_lnn_270
# Processing block: als_lst_248
# Processing block: als_mis_218
# Processing block: als_mis_267
# Processing block: als_mis_272
# Processing block: als_mkl_200
# Processing block: als_mkl_233
# Processing block: als_mkt_244
# Processing block: als_ml _231
# Processing block: als_mrt_256
# Processing block: als_nks_206
# Processing block: als_nr _202
# Processing block: als_pkn_282
# Processing block: als_pnt_245
# Processing block: als_pr _262
# Processing block: als_prt_205
# Processing block: als_pt _246
# Processing block: als_ptr_203
# Processing block: als_pts_260
# Processing block: als_px _212
# Processing block: als_rjn_286
# Processing block: als_rlf_200
# Processing block: als_rlf_219
# Processing block: als_rlf_227
# Processing block: als_rlf_255
# Processing block: als_rlf_293
# Processing block: als_rnt_280
# Processing block: als_rpr_205
# Processing block: als_rxr_209
# Processing block: als_s0 _217
# Processing block: als_s0 _289
# Processing block: als_sai_209
# Processing block: als_skt_245
# Processing block: als_skt_295
# Processing block: als_skt_299
# Processing block: als_sm0_222
# Processing block: als_sm0_226
# Processing block: als_sm0_229
# Processing block: als_sr _261
# Processing block: als_sr _286
# Processing block: als_tfs_247
# Processing block: als_tft_239
# Processing block: als_tkl_227
# Processing block: als_tlr_253
# Processing block: als_tm0_206
# Processing block: als_tns_211
# Processing block: als_tr _227
# Processing block: als_trn_292
# Processing block: als_tt _289
# Processing block: als_wes_220
# Processing block: als_xn _264
# Processing block: alt_ant_239
# Processing block: alt_eri_213
# Processing block: alt_flr_253
# Processing block: alt_hrn_238
# Processing block: alt_kr _215
# Processing block: alt_krs_254
# Processing block: alt_mln_276
# Processing block: alt_mrs_282
# Processing block: alt_nkl_206
# Processing block: alt_pl _213
# Processing block: alx_alk_298
# Processing block: alx_atm_261
# Processing block: alx_hrt_250
# Processing block: alx_jl _290
# Processing block: alx_jsn_266
# Processing block: alx_kk _261
# Processing block: alx_knk_213
# Processing block: alx_ktm_202
# Processing block: alx_mxl_200
# Processing block: alx_mxl_286
# Processing block: alx_rt _207
# Processing block: alx_s0_226
# Processing block: alx_ss _236
# Processing block: alx_tft_238
# Processing block: alx_tt _244
# Processing block: am _afn_223
# Processing block: am _aln_273
# Processing block: am _als_210
# Processing block: am _ere_237
# Processing block: am _ere_254
# Processing block: am _ere_299
# Processing block: am _flr_200
# Processing block: am _flr_261
# Processing block: am _fls_224
# Processing block: am _frn_243
# Processing block: am _kl _201
# Processing block: am _kl _216
# Processing block: am _kl _240
# Processing block: am _kl _246
# Processing block: am _kn0_217
# Processing block: am _krn_245
# Processing block: am _krn_248
# Processing block: am _krn_257
# Processing block: am _krn_294
# Processing block: am _krs_225
# Processing block: am _krs_280
# Processing block: am _krs_286
# Processing block: am _krs_291
# Processing block: am _ktn_203
# Processing block: am _l f_202
# Processing block: am _l f_250
# Processing block: am _l f_283
# Processing block: am _lkn_255
# Processing block: am _n n_232
# Processing block: am _new_277
# Processing block: am _p f_299
# Processing block: am _sim_231
# Processing block: am _xrl_235
# Processing block: am _xrs_245
# Processing block: amk_kl _212
# Processing block: amk_kl _274
# Processing block: amk_kl _286
# Processing block: aml_ an_283
# Processing block: aml_0rs_210
# Processing block: aml_0rs_232
# Processing block: aml_0rs_239
# Processing block: aml_0rs_277
# Processing block: aml_0rs_289
# Processing block: aml_0rs_290
# Processing block: aml_afn_223
# Processing block: aml_afn_233
# Processing block: aml_afn_256
# Processing block: aml_afn_280
# Processing block: aml_ans_279
# Processing block: aml_ark_226
# Processing block: aml_ash_227
# Processing block: aml_chr_257
# Processing block: aml_chr_276
# Processing block: aml_fns_262
# Processing block: aml_frn_205
# Processing block: aml_frn_228
# Processing block: aml_frn_278
# Processing block: aml_frn_285
# Processing block: aml_hri_224
# Processing block: aml_hub_272
# Processing block: aml_jfr_293
# Processing block: aml_jks_277
# Processing block: aml_jks_290
# Processing block: aml_jns_243
# Processing block: aml_kl _234
# Processing block: aml_kl _256
# Processing block: aml_kl _270
# Processing block: aml_kl _290
# Processing block: aml_krf_221
# Processing block: aml_krp_290
# Processing block: aml_krs_239
# Processing block: aml_mis_225
# Processing block: aml_mis_241
# Processing block: aml_mis_289
# Processing block: aml_mr _288
# Processing block: aml_mrf_270
# Processing block: aml_mrk_248
# Processing block: aml_msn_270
# Processing block: aml_nee_283
# Processing block: aml_new_236
# Processing block: aml_new_244
# Processing block: aml_new_270
# Processing block: aml_npl_214
# Processing block: aml_nr0_209
# Processing block: aml_nr0_273
# Processing block: aml_nr0_293
# Processing block: aml_prs_225
# Processing block: aml_prs_238
# Processing block: aml_prs_263
# Processing block: aml_rs _289
# Processing block: aml_rtn_201
# Processing block: aml_sln_224
# Processing block: aml_sln_237
# Processing block: aml_sln_282
# Processing block: aml_tn _202
# Processing block: aml_tn _277
# Processing block: aml_tn _298
# Processing block: aml_ubb_266
# Processing block: amn_ hr_286
# Processing block: amn_ kr_254
# Processing block: amn_ tn_235
# Processing block: amn_als_205
# Processing block: amn_anj_263
# Processing block: amn_h t_262
# Processing block: amn_hrt_209
# Processing block: amn_hrt_226
# Processing block: amn_hrt_247
# Processing block: amn_hrt_272
# Processing block: amn_hrt_281
# Processing block: amn_jns_204
# Processing block: amn_jns_237
# Processing block: amn_jns_259
# Processing block: amn_jns_297
# Processing block: amn_js _298
# Processing block: amn_jsf_235
# Processing block: amn_jsf_296
# Processing block: amn_km _209
# Processing block: amn_km _288
# Processing block: amn_krl_216
# Processing block: amn_ln _269
# Processing block: amn_mkt_273
# Processing block: amn_mt _274
# Processing block: amn_nks_274
# Processing block: amn_smn_217
# Processing block: amn_sn0_246
# Processing block: amn_sts_238
# Processing block: amn_tkl_222
# Processing block: amn_tks_201
# Processing block: amn_tns_245
# Processing block: amn_tns_284
# Processing block: amn_tpr_233
# Processing block: amn_tpr_287
# Processing block: amn_tpr_298
# Processing block: amn_trn_291
# Processing block: amn_trs_267
# Processing block: amn_x s_252
# Processing block: amp_als_258
# Processing block: amp_jfr_201
# Processing block: amp_jkp_205
# Processing block: amp_jkp_212
# Processing block: amp_jx _209
# Processing block: amp_jx _247
# Processing block: amp_jx _256
# Processing block: amp_jx _264
# Processing block: amp_lps_222
# Processing block: amp_prs_256
# Processing block: amp_prt_226
# Processing block: amp_prt_288
# Processing block: amp_sim_206
# Processing block: amr_ kn_201
# Processing block: amr_alm_268
# Processing block: amr_apr_243
# Processing block: amr_jnf_245
# Processing block: amr_jnf_265
# Processing block: amr_jnf_282
# Processing block: amr_klt_293
# Processing block: amr_lnk_246
# Processing block: amr_slr_262
# Processing block: amr_spr_294
# Processing block: amr_trn_200
# Processing block: ams_sim_210
# Processing block: amt_atk_281
# Processing block: amt_krn_221
# Processing block: amt_prs_256
# Processing block: amt_wes_281
# Processing block: an _ mr_269
# Processing block: an _ pr_289
# Processing block: an _alm_231
# Processing block: an _art_228
# Processing block: an _ast_207
# Processing block: an _ast_256
# Processing block: an _ast_262
# Processing block: an _ast_266
# Processing block: an _ast_295
# Processing block: an _hmn_219
# Processing block: an _hns_270
# Processing block: an _hpr_201
# Processing block: an _hpr_269
# Processing block: an _hpr_278
# Processing block: an _hpr_299
# Processing block: an _jn _256
# Processing block: an _jn _265
# Processing block: an _jn0_238
# Processing block: an _jn0_277
# Processing block: an _klt_204
# Processing block: an _klt_243
# Processing block: an _knt_210
# Processing block: an _krn_237
# Processing block: an _lps_293
# Processing block: an _ls _251
# Processing block: an _ltr_288
# Processing block: an _mel_217
# Processing block: an _mez_242
# Processing block: an _mis_285
# Processing block: an _mk _205
# Processing block: an _mk _280
# Processing block: an _mkl_264
# Processing block: an _ms _212
# Processing block: an _ms _285
# Processing block: an _ms _293
# Processing block: an _msk_241
# Processing block: an _mts_285
# Processing block: an _prt_206
# Processing block: an _prt_258
# Processing block: an _prt_281
# Processing block: an _rln_287
# Processing block: an _rnl_298
# Processing block: an _rsl_204
# Processing block: an _rsl_220
# Processing block: an _rsl_259
# Processing block: an _skt_219
# Processing block: an _skt_256
# Processing block: an _sm0_230
# Processing block: an _sm0_291
# Processing block: an _snf_248
# Processing block: an _stm_253
# Processing block: an _tkr_221
# Processing block: an _tmn_260
# Processing block: an _tn _257
# Processing block: an _tns_292
# Processing block: an _trn_250
# Processing block: an0_0rs_294
# Processing block: an0_a a_267
# Processing block: an0_alm_297
# Processing block: an0_als_212
# Processing block: an0_als_266
# Processing block: an0_als_292
# Processing block: an0_an0_215
# Processing block: an0_atm_247
# Processing block: an0_atm_269
# Processing block: an0_fk _291
# Processing block: an0_fkf_289
# Processing block: an0_flr_239
# Processing block: an0_flr_257
# Processing block: an0_flr_290
# Processing block: an0_fns_268
# Processing block: an0_jnf_281
# Processing block: an0_jns_258
# Processing block: an0_jst_265
# Processing block: an0_kln_209
# Processing block: an0_kln_245
# Processing block: an0_kr _219
# Processing block: an0_krf_214
# Processing block: an0_krf_270
# Processing block: an0_krf_279
# Processing block: an0_krs_248
# Processing block: an0_krs_271
# Processing block: an0_krs_278
# Processing block: an0_lak_217
# Processing block: an0_lk _201
# Processing block: an0_lk _218
# Processing block: an0_lk_293
# Processing block: an0_lr _280
# Processing block: an0_mis_246
# Processing block: an0_mlr_200
# Processing block: an0_mlr_207
# Processing block: an0_mlr_225
# Processing block: an0_mlr_243
# Processing block: an0_mlr_296
# Processing block: an0_mr _291
# Processing block: an0_nxl_278
# Processing block: an0_prp_238
# Processing block: an0_prs_294
# Processing block: an0_ptl_202
# Processing block: an0_rtr_216
# Processing block: an0_sks_232
# Processing block: an0_skt_296
# Processing block: an0_tft_235
# Processing block: an0_tmp_232
# Processing block: an0_trs_204
# Processing block: an0_trs_299
# Processing block: an_flj_269
# Processing block: an_jsf_254
# Processing block: an_mis_216
# Processing block: an_skt_285
# Processing block: an_snk_284
# Processing block: anf_kr _297
# Processing block: anf_prs_224
# Processing block: anf_prs_230
# Processing block: anf_prs_282
# Processing block: anj_ hl_233
# Processing block: anj_ hl_298
# Processing block: anj_ hr_207
# Processing block: anj_ sk_284
# Processing block: anj_0mp_292
# Processing block: anj_alm_250
# Processing block: anj_apr_236
# Processing block: anj_jsn_215
# Processing block: anj_jsn_237
# Processing block: anj_jsn_262
# Processing block: anj_kt _251
# Processing block: anj_kt _273
# Processing block: anj_ls _275
# Processing block: anj_mr _207
# Processing block: anj_nor_229
# Processing block: anj_pns_264
# Processing block: anj_prk_216
# Processing block: anj_prt_289
# Processing block: anj_rjn_234
# Processing block: anj_rjn_284
# Processing block: anj_rpk_261
# Processing block: anj_shr_233
# Processing block: anj_skt_221
# Processing block: anj_skt_236
# Processing block: anj_skt_241
# Processing block: anj_stf_243
# Processing block: anj_stf_273
# Processing block: anj_tft_218
# Processing block: anj_tmp_292
# Processing block: anj_tp0_245
# Processing block: anj_ts _236
# Processing block: anj_ts _284
# Processing block: anj_ts _295
# Processing block: anj_xl _209
# Processing block: ank_ mk_289
# Processing block: ank_alk_268
# Processing block: ank_am _292
# Processing block: ank_ant_238
# Processing block: ank_arn_245
# Processing block: ank_ast_205
# Processing block: ank_axl_266
# Processing block: ank_axl_293
# Processing block: ank_con_235
# Processing block: ank_f a_251
# Processing block: ank_f a_274
# Processing block: ank_f a_294
# Processing block: ank_fls_202
# Processing block: ank_hhs_265
# Processing block: ank_hrn_255
# Processing block: ank_jn _240
# Processing block: ank_jns_254
# Processing block: ank_jsk_247
# Processing block: ank_jsm_215
# Processing block: ank_jsn_221
# Processing block: ank_k0 _265
# Processing block: ank_kin_253
# Processing block: ank_kmp_264
# Processing block: ank_kms_232
# Processing block: ank_kms_266
# Processing block: ank_kms_276
# Processing block: ank_kms_291
# Processing block: ank_krs_273
# Processing block: ank_lk _216
# Processing block: ank_lpj_282
# Processing block: ank_lrn_204
# Processing block: ank_ls _232
# Processing block: ank_ls _299
# Processing block: ank_mkl_210
# Processing block: ank_mr _264
# Processing block: ank_mxl_223
# Processing block: ank_nt _240
# Processing block: ank_och_297
# Processing block: ank_pft_233
# Processing block: ank_prn_273
# Processing block: ank_rpr_271
# Processing block: ank_rpr_273
# Processing block: ank_rt _212
# Processing block: ank_sfj_213
# Processing block: ank_smn_272
# Processing block: ank_stf_280
# Processing block: ank_tft_254
# Processing block: ank_tm0_226
# Processing block: ank_tm0_228
# Processing block: ank_tm0_247
# Processing block: ank_tm0_250
# Processing block: ank_tm0_295
# Processing block: ank_tmr_288
# Processing block: ank_tmr_298
# Processing block: ank_tn _208
# Processing block: ank_tn _234
# Processing block: anl_ ss_226
# Processing block: anl_klr_287
# Processing block: anl_krn_298
# Processing block: anl_r_222
# Processing block: anm_jn_273
# Processing block: anm_skt_220
# Processing block: anm_tfn_249
# Processing block: ann_krt_262
# Processing block: ann_mkn_257
# Processing block: ann_mln_237
# Processing block: ann_rl _212
# Processing block: anr_alk_220
# Processing block: anr_hns_285
# Processing block: anr_krf_221
# Processing block: anr_krl_263
# Processing block: anr_krs_297
# Processing block: anr_kt _296
# Processing block: anr_lk _223
# Processing block: ans_ ml_222
# Processing block: ans_ark_254
# Processing block: ans_fl_204
# Processing block: ans_jns_298
# Processing block: ans_mar_249
# Processing block: ans_tfs_223
# Processing block: ant_ pr_249
# Processing block: ant_ sl_285
# Processing block: ant_(th_207
# Processing block: ant_(th_233
# Processing block: ant_alk_211
# Processing block: ant_alk_268
# Processing block: ant_aln_207
# Processing block: ant_aln_276
# Processing block: ant_aln_283
# Processing block: ant_als_247
# Processing block: ant_als_261
# Processing block: ant_ans_244
# Processing block: ant_ans_282
# Processing block: ant_ant_235
# Processing block: ant_ant_273
# Processing block: ant_ant_289
# Processing block: ant_ant_293
# Processing block: ant_ast_259
# Processing block: ant_at _215
# Processing block: ant_at _283
# Processing block: ant_atm_282
# Processing block: ant_ats_275
# Processing block: ant_axl_228
# Processing block: ant_fks_204
# Processing block: ant_fr _264
# Processing block: ant_frn_292
# Processing block: ant_frn_298
# Processing block: ant_frs_288
# Processing block: ant_frt_258
# Processing block: ant_hn _285
# Processing block: ant_hrp_204
# Processing block: ant_hrt_221
# Processing block: ant_jnf_251
# Processing block: ant_jns_209
# Processing block: ant_jsf_241
# Processing block: ant_jsk_213
# Processing block: ant_jx _246
# Processing block: ant_k0r_228
# Processing block: ant_kfn_245
# Processing block: ant_kln_294
# Processing block: ant_kmp_211
# Processing block: ant_kmp_289
# Processing block: ant_kmp_296
# Processing block: ant_kn _261
# Processing block: ant_krs_211
# Processing block: ant_krs_216
# Processing block: ant_krs_225
# Processing block: ant_krs_286
# Processing block: ant_krs_298
# Processing block: ant_ks _274
# Processing block: ant_l p_292
# Processing block: ant_lkn_212
# Processing block: ant_lln_231
# Processing block: ant_lln_299
# Processing block: ant_lmp_266
# Processing block: ant_lnt_249
# Processing block: ant_lrn_235
# Processing block: ant_mis_212
# Processing block: ant_mis_223
# Processing block: ant_mk _277
# Processing block: ant_mr _206
# Processing block: ant_mrn_220
# Processing block: ant_ms _226
# Processing block: ant_n r_204
# Processing block: ant_n r_247
# Processing block: ant_n r_256
# Processing block: ant_n r_264
# Processing block: ant_n r_287
# Processing block: ant_nat_264
# Processing block: ant_nr0_285
# Processing block: ant_ntx_204
# Processing block: ant_pat_297
# Processing block: ant_pn _274
# Processing block: ant_prk_204
# Processing block: ant_prk_210
# Processing block: ant_prk_227
# Processing block: ant_prk_249
# Processing block: ant_prk_283
# Processing block: ant_prt_227
# Processing block: ant_prt_296
# Processing block: ant_ptr_251
# Processing block: ant_ran_259
# Processing block: ant_rfr_223
# Processing block: ant_rs _273
# Processing block: ant_sml_224
# Processing block: ant_sml_254
# Processing block: ant_sou_248
# Processing block: ant_ter_219
# Processing block: ant_tft_235
# Processing block: ant_tmr_279
# Processing block: ant_tmr_283
# Processing block: ant_tms_298
# Processing block: ant_trr_209
# Processing block: ant_trs_293
# Processing block: ant_tt _236
# Processing block: ant_xrt_295
# Processing block: anx_xrt_212
# Processing block: apk_jrt_251
# Processing block: apk_kr _289
# Processing block: apk_ksn_219
# Processing block: apk_mic_224
# Processing block: apl_jms_269
# Processing block: apn_ tr_262
# Processing block: apn_aml_212
# Processing block: apn_aml_237
# Processing block: apn_aml_245
# Processing block: apn_aml_255
# Processing block: apn_aml_267
# Processing block: apn_hns_270
# Processing block: apn_kim_281
# Processing block: apn_s0_256
# Processing block: app_ant_213
# Processing block: app_hlt_242
# Processing block: app_krp_268
# Processing block: app_skt_234
# Processing block: app_tnl_260
# Processing block: apr_als_260
# Processing block: apr_als_265
# Processing block: apr_amn_224
# Processing block: apr_ant_215
# Processing block: apr_ask_213
# Processing block: apr_hrn_206
# Processing block: apr_krs_227
# Processing block: apr_lsn_258
# Processing block: apr_ptr_250
# Processing block: apr_ptr_263
# Processing block: apr_ptr_277
# Processing block: apr_ptr_280
# Processing block: apr_ptr_283
# Processing block: apr_r_215
# Processing block: apr_rpr_212
# Processing block: apr_rpr_214
# Processing block: apr_rpr_226
# Processing block: apr_rpr_232
# Processing block: apr_rpr_262
# Processing block: aps_kps_234
# Processing block: aps_mxl_281
# Processing block: aps_nns_268
# Processing block: aps_rkr_247
# Processing block: apt_ast_265
# Processing block: apt_hs _298
# Processing block: ar _ak _273
# Processing block: ar _kfm_231
# Processing block: ar _prt_293
# Processing block: ar _ptn_248
# Processing block: ar _rs _239
# Processing block: ar _rs _260
# Processing block: ar _trn_285
# Processing block: ar0_ l _299
# Processing block: ar0_apr_255
# Processing block: ar0_kln_269
# Processing block: ar0_krl_220
# Processing block: ar0_krt_209
# Processing block: ar0_l f_299
# Processing block: ar0_mrk_216
# Processing block: ar0_mrk_218
# Processing block: ar0_mrk_249
# Processing block: ar0_prk_238
# Processing block: arj_jms_255
# Processing block: arj_jms_267
# Processing block: arj_jms_277
# Processing block: arj_jms_278
# Processing block: ark_ fl_253
# Processing block: ark_ rn_223
# Processing block: ark_afn_241
# Processing block: ark_ant_259
# Processing block: ark_apr_234
# Processing block: ark_ast_286
# Processing block: ark_fkt_292
# Processing block: ark_jms_264
# Processing block: ark_jn _270
# Processing block: ark_jns_209
# Processing block: ark_jns_214
# Processing block: ark_jns_222
# Processing block: ark_k0r_288
# Processing block: ark_ln _243
# Processing block: ark_ln _260
# Processing block: ark_ln _266
# Processing block: ark_mk _267
# Processing block: ark_pit_241
# Processing block: ark_por_223
# Processing block: ark_prn_209
# Processing block: ark_prn_221
# Processing block: ark_prn_280
# Processing block: ark_prt_220
# Processing block: ark_prt_264
# Processing block: ark_prt_267
# Processing block: ark_pxp_294
# Processing block: ark_rl _223
# Processing block: ark_rl _247
# Processing block: ark_rmr_217
# Processing block: ark_rn _203
# Processing block: ark_rn _275
# Processing block: ark_rn _293
# Processing block: ark_tlr_284
# Processing block: ark_tns_259
# Processing block: ark_xmt_297
# Processing block: arl_kfn_299
# Processing block: arl_kl _236
# Processing block: arl_mnt_288
# Processing block: arm_lks_208
# Processing block: arm_lks_212
# Processing block: arm_lks_251
# Processing block: arm_lts_211
# Processing block: arm_tnl_254
# Processing block: arn_  n_247
# Processing block: arn_als_238
# Processing block: arn_an _233
# Processing block: arn_an _241
# Processing block: arn_an0_276
# Processing block: arn_anj_292
# Processing block: arn_arn_282
# Processing block: arn_ast_209
# Processing block: arn_ath_289
# Processing block: arn_chr_231
# Processing block: arn_fk _281
# Processing block: arn_flr_238
# Processing block: arn_fst_217
# Processing block: arn_fst_258
# Processing block: arn_gut_267
# Processing block: arn_har_243
# Processing block: arn_hjs_243
# Processing block: arn_hl _245
# Processing block: arn_hn _248
# Processing block: arn_hnt_266
# Processing block: arn_jn _253
# Processing block: arn_jn _293
# Processing block: arn_jsk_247
# Processing block: arn_kll_248
# Processing block: arn_kt_214
# Processing block: arn_lk _212
# Processing block: arn_mis_228
# Processing block: arn_mk _233
# Processing block: arn_mkl_241
# Processing block: arn_mkl_296
# Processing block: arn_mr _288
# Processing block: arn_nn _271
# Processing block: arn_pk _222
# Processing block: arn_pn _275
# Processing block: arn_por_265
# Processing block: arn_prk_205
# Processing block: arn_prs_237
# Processing block: arn_prt_283
# Processing block: arn_prt_289
# Processing block: arn_ptr_216
# Processing block: arn_r p_221
# Processing block: arn_r p_244
# Processing block: arn_rn _235
# Processing block: arn_rt _262
# Processing block: arn_san_292
# Processing block: arn_snx_226
# Processing block: arn_snx_227
# Processing block: arn_snx_261
# Processing block: arn_snx_296
# Processing block: arn_tfs_215
# Processing block: arn_tmn_203
# Processing block: arn_tms_284
# Processing block: arn_tns_268
# Processing block: arn_xnk_231
# Processing block: arp_kl _251
# Processing block: arp_prn_291
# Processing block: arr_krl_212
# Processing block: ars_an _275
# Processing block: ars_klt_222
# Processing block: ars_knt_219
# Processing block: ars_knt_230
# Processing block: ars_knt_233
# Processing block: ars_krs_215
# Processing block: ars_nr0_245
# Processing block: ars_stn_293
# Processing block: ars_t n_293
# Processing block: ars_tn _219
# Processing block: ars_tn _226
# Processing block: ars_tn _275
# Processing block: ars_tn _282
# Processing block: ars_tns_219
# Processing block: art_ fr_294
# Processing block: art_ l _299
# Processing block: art_ nk_217
# Processing block: art_afr_206
# Processing block: art_afr_231
# Processing block: art_afr_246
# Processing block: art_als_271
# Processing block: art_als_274
# Processing block: art_flr_276
# Processing block: art_hfm_229
# Processing block: art_kks_297
# Processing block: art_krk_231
# Processing block: art_krl_219
# Processing block: art_krl_232
# Processing block: art_krl_298
# Processing block: art_krs_211
# Processing block: art_krs_247
# Processing block: art_krs_287
# Processing block: art_lnk_211
# Processing block: art_ls _247
# Processing block: art_mis_214
# Processing block: art_mrk_270
# Processing block: art_nor_258
# Processing block: art_par_218
# Processing block: art_ptr_258
# Processing block: art_rn _293
# Processing block: art_rs _250
# Processing block: art_sr _231
# Processing block: art_tfn_268
# Processing block: art_tnl_245
# Processing block: as _als_221
# Processing block: as _prt_209
# Processing block: as _skr_218
# Processing block: as _sr _216
# Processing block: as_mrt_207
# Processing block: ask__243
# Processing block: ask__258
# Processing block: ask__260
# Processing block: ask_lnt_210
# Processing block: ask_nr _293
# Processing block: ask_nr0_243
# Processing block: ask_nr0_288
# Processing block: ask_prt_222
# Processing block: ask_srs_222
# Processing block: ask_tn _224
# Processing block: asl_a k_231
# Processing block: asl_a k_279
# Processing block: asl_a k_281
# Processing block: asl_a k_299
# Processing block: asl_krs_276
# Processing block: asn_nr0_236
# Processing block: asn_s0 _208
# Processing block: asp_hn _221
# Processing block: asp_hn _233
# Processing block: asp_hn_298
# Processing block: asp_jms_217
# Processing block: asp_krs_268
# Processing block: asp_mr _288
# Processing block: asp_ptr_244
# Processing block: asp_sps_257
# Processing block: ast_ sp_200
# Processing block: ast_alm_236
# Processing block: ast_arn_267
# Processing block: ast_ast_266
# Processing block: ast_fk _204
# Processing block: ast_fst_214
# Processing block: ast_fst_239
# Processing block: ast_fst_240
# Processing block: ast_fst_298
# Processing block: ast_jn _244
# Processing block: ast_jnf_200
# Processing block: ast_l k_230
# Processing block: ast_lar_261
# Processing block: ast_mrf_211
# Processing block: ast_n r_242
# Processing block: ast_n. _239
# Processing block: ast_oro_277
# Processing block: ast_pnk_219
# Processing block: ast_trs_226
# Processing block: at _frt_226
# Processing block: at _hrn_256
# Processing block: at _jns_223
# Processing block: at _jst_273
# Processing block: at _krf_296
# Processing block: at _krs_220
# Processing block: at _krt_291
# Processing block: at _lns_202
# Processing block: at _lrn_200
# Processing block: at _mrs_213
# Processing block: at _mrs_267
# Processing block: at _mrs_271
# Processing block: at _nn _297
# Processing block: at _nr0_297
# Processing block: at _pr _208
# Processing block: at _pr _263
# Processing block: at _pr _284
# Processing block: at _prn_263
# Processing block: at _prt_207
# Processing block: at _prt_224
# Processing block: at _ptr_273
# Processing block: at _rn _258
# Processing block: at _rpr_216
# Processing block: at _sls_204
# Processing block: at _snt_210
# Processing block: at _spr_208
# Processing block: at _ssn_274
# Processing block: at _ssn_282
# Processing block: at _ssn_285
# Processing block: at _str_266
# Processing block: at _tft_230
# Processing block: at _tft_262
# Processing block: at _tft_279
# Processing block: at _tft_280
# Processing block: at _tlr_206
# Processing block: at _tlr_291
# Processing block: at_ ar_267
# Processing block: at_ ar_296
# Processing block: at_mkl_233
# Processing block: atf_prk_230
# Processing block: atk_ kk_278
# Processing block: atk_alj_215
# Processing block: atk_alm_223
# Processing block: atk_ats_286
# Processing block: atk_hrp_237
# Processing block: atk_kk _214
# Processing block: atk_kk _237
# Processing block: atk_kk _259
# Processing block: atk_m0 _281
# Processing block: atk_mnt_293
# Processing block: atk_n k_282
# Processing block: atk_prt_219
# Processing block: atk_snx_280
# Processing block: atk_stf_252
# Processing block: atk_tft_235
# Processing block: atk_tms_279
# Processing block: atl_jrm_239
# Processing block: atm_als_203
# Processing block: atm_als_208
# Processing block: atm_als_228
# Processing block: atm_ark_274
# Processing block: atm_ast_277
# Processing block: atm_fj _204
# Processing block: atm_flp_236
# Processing block: atm_hls_295
# Processing block: atm_hns_262
# Processing block: atm_jnk_218
# Processing block: atm_jnk_277
# Processing block: atm_jos_291
# Processing block: atm_jsf_211
# Processing block: atm_jsf_235
# Processing block: atm_jsf_236
# Processing block: atm_jsf_275
# Processing block: atm_jsn_267
# Processing block: atm_klr_236
# Processing block: atm_kns_208
# Processing block: atm_kns_249
# Processing block: atm_ksm_283
# Processing block: atm_kst_243
# Processing block: atm_lk _258
# Processing block: atm_ln _284
# Processing block: atm_mis_214
# Processing block: atm_mis_243
# Processing block: atm_mkl_235
# Processing block: atm_mkl_269
# ...
# Processing block: trn_pk _232
# Processing block: trn_rs _211
# Processing block: trn_rs _229
# Processing block: trn_rs _248
# Processing block: trn_rs _259
# Processing block: trn_rs _268
# Processing block: trn_rs _282
# Processing block: trn_tfn_289
# Processing block: trp_ls _226
# Processing block: trr_alk_214
# Processing block: trr_alk_254
# Processing block: trr_hrs_233
# Processing block: trr_jn _283
# Processing block: trr_lsf_294
# Processing block: trr_mis_277
# Processing block: trr_mt _274
# Processing block: trr_rpr_219
# Processing block: trr_rpr_225
# Processing block: trr_xls_260
# Processing block: trs_a n_234
# Processing block: trs_a n_235
# Processing block: trs_alm_239
# Processing block: trs_aml_216
# Processing block: trs_aml_237
# Processing block: trs_aml_242
# Processing block: trs_aml_264
# Processing block: trs_aml_297
# Processing block: trs_an0_200
# Processing block: trs_anj_288
# Processing block: trs_ant_237
# Processing block: trs_ant_260
# Processing block: trs_ant_270
# Processing block: trs_ast_210
# Processing block: trs_bry_262
# Processing block: trs_hs _235
# Processing block: trs_jkl_202
# Processing block: trs_jms_271
# Processing block: trs_kmp_290
# Processing block: trs_kns_238
# Processing block: trs_kpr_208
# Processing block: trs_krs_271
# Processing block: trs_krt_231
# Processing block: trs_mkl_271
# Processing block: trs_mln_223
# Processing block: trs_p0 _267
# Processing block: trs_prp_227
# Processing block: trs_rs _263
# Processing block: trs_rs _277
# Processing block: trs_s0 _276
# Processing block: trs_tnl_252
# Processing block: trs_trl_202
# Processing block: trs_trs_237
# Processing block: trs_trs_271
# Processing block: trs_xnt_278
# Processing block: trt_aks_220
# Processing block: trt_frn_272
# Processing block: trt_h k_215
# Processing block: trt_jn0_238
# Processing block: trt_kks_228
# Processing block: trt_mkn_265
# Processing block: trt_mxl_217
# Processing block: trt_nt _254
# Processing block: trt_prn_215
# Processing block: trt_snx_253
# Processing block: ts _smr_296
# Processing block: ts _tnl_256
# Processing block: ts_mxl_245
# Processing block: tsf_fks_279
# Processing block: tsf_js _253
# Processing block: tsf_lsp_299
# Processing block: tsf_mic_246
# Processing block: tsf_pnt_200
# Processing block: tsm_smp_212
# Processing block: tsn_ast_273
# Processing block: tsn_hrt_255
# Processing block: tsn_rjr_226
# Processing block: tsr_new_282
# Processing block: tss_aa _206
# Processing block: tss_nfr_205
# Processing block: tss_nt _236
# Processing block: tss_nt _294
# Processing block: tss_prn_214
# Processing block: tss_ptr_212
# Processing block: tss_ptr_285
# Processing block: tss_tm _218
# Processing block: tst_jmn_236
# Processing block: tst_jmn_252
# Processing block: tst_jmn_269
# Processing block: tst_jmn_275
# Processing block: tst_jmn_295
# Processing block: tst_jsf_293
# Processing block: tst_kpl_283
# Processing block: tst_pts_243
# Processing block: tst_pts_249
# Processing block: tst_pts_285
# Processing block: tt _ ss_284
# Processing block: tt _a n_227
# Processing block: tt _a n_245
# Processing block: tt _a n_250
# Processing block: tt _a n_285
# Processing block: tt _a n_296
# Processing block: tt _alf_225
# Processing block: tt _alk_201
# Processing block: tt _alk_242
# Processing block: tt _alm_224
# Processing block: tt _als_248
# Processing block: tt _als_287
# Processing block: tt _amn_202
# Processing block: tt _amn_288
# Processing block: tt _anj_249
# Processing block: tt _anj_257
# Processing block: tt _anj_272
# Processing block: tt _anj_285
# Processing block: tt _anj_291
# Processing block: tt _art_248
# Processing block: tt _ast_202
# Processing block: tt _ast_231
# Processing block: tt _ast_288
# Processing block: tt _ast_299
# Processing block: tt _atr_209
# Processing block: tt _axl_235
# Processing block: tt _axn_212
# Processing block: tt _flk_236
# Processing block: tt _flk_250
# Processing block: tt _flk_253
# Processing block: tt _flk_282
# Processing block: tt _fln_213
# Processing block: tt _flr_257
# Processing block: tt _frn_205
# Processing block: tt _frn_247
# Processing block: tt _frn_268
# Processing block: tt _frn_277
# Processing block: tt _har_250
# Processing block: tt _hl _240
# Processing block: tt _hl _275
# Processing block: tt _hrn_228
# Processing block: tt _jms_203
# Processing block: tt _kl _295
# Processing block: tt _klk_283
# Processing block: tt _kls_269
# Processing block: tt _kns_216
# Processing block: tt _kns_290
# Processing block: tt _kr _255
# Processing block: tt _krl_263
# Processing block: tt _krl_286
# Processing block: tt _krn_257
# Processing block: tt _krn_266
# Processing block: tt _krn_298
# Processing block: tt _krs_232
# Processing block: tt _krs_239
# Processing block: tt _krs_263
# Processing block: tt _krs_274
# Processing block: tt _krs_281
# Processing block: tt _krt_234
# Processing block: tt _ksr_293
# Processing block: tt _l l_257
# Processing block: tt _lnt_206
# Processing block: tt _lnt_212
# Processing block: tt _lr _222
# Processing block: tt _ls _226
# Processing block: tt _lsl_228
# Processing block: tt _m0s_266
# Processing block: tt _mis_235
# Processing block: tt _mkl_210
# Processing block: tt _mkl_228
# Processing block: tt _mkl_268
# Processing block: tt _mln_285
# Processing block: tt _mlr_244
# Processing block: tt _mls_221
# Processing block: tt _mnt_293
# Processing block: tt _mrk_257
# Processing block: tt _mrk_283
# Processing block: tt _n n_245
# Processing block: tt _nf0_235
# Processing block: tt _nkl_226
# Processing block: tt _nkl_242
# Processing block: tt _nr0_238
# Processing block: tt _nr0_242
# Processing block: tt _nr0_245
# Processing block: tt _pl _254
# Processing block: tt _pnt_273
# Processing block: tt _prj_226
# Processing block: tt _prn_258
# Processing block: tt _prp_234
# Processing block: tt _prs_209
# Processing block: tt _prs_221
# Processing block: tt _prs_285
# Processing block: tt _ptl_226
# Processing block: tt _rmn_216
# Processing block: tt _rpk_209
# Processing block: tt _rpr_222
# Processing block: tt _rpr_297
# Processing block: tt _rt _211
# Processing block: tt _sm0_250
# Processing block: tt _smp_273
# Processing block: tt _snt_299
# Processing block: tt _sr _247
# Processing block: tt _sr _263
# Processing block: tt _sr _277
# Processing block: tt _stf_208
# Processing block: tt _stf_231
# Processing block: tt _stf_291
# Processing block: tt _stn_288
# Processing block: tt _t a_294
# Processing block: tt _tfn_269
# Processing block: tt _tms_229
# Processing block: tt _tn _240
# Processing block: tt _tns_251
# Processing block: tt _trf_265
# Processing block: tt _trl_208
# Processing block: tt _trn_200
# Processing block: tt _trs_219
# Processing block: tt _trs_265
# Processing block: tt _trs_272
# Processing block: tt _trs_288
# Processing block: tt _tt _231
# Processing block: tt _xlt_240
# Processing block: tt _xlt_262
# Processing block: ttf_alm_211
# Processing block: ttf_frn_209
# Processing block: ttf_kk _264
# Processing block: ttf_kks_232
# Processing block: ttf_ks _291
# Processing block: ttf_l f_240
# Processing block: ttf_lk _290
# Processing block: ttf_sol_213
# Processing block: ttf_sr _226
# Processing block: ttj_a k_282
# Processing block: ttj_a k_294
# Processing block: ttj_alm_221
# Processing block: ttj_flt_222
# Processing block: ttj_klp_203
# Processing block: ttk_aml_297
# Processing block: ttk_an _238
# Processing block: ttk_ark_210
# Processing block: ttk_bro_274
# Processing block: ttk_flp_210
# Processing block: ttk_flp_273
# Processing block: ttk_jrt_242
# Processing block: ttk_kl _204
# Processing block: ttk_kln_247
# Processing block: ttk_krl_249
# Processing block: ttk_lnr_234
# Processing block: ttk_mlr_211
# Processing block: ttk_mxl_244
# Processing block: ttk_nns_243
# Processing block: ttk_nns_283
# Processing block: ttk_nns_295
# Processing block: ttk_p0n_270
# Processing block: ttk_prk_270
# Processing block: ttk_pts_274
# Processing block: ttk_rn _251
# Processing block: ttk_sm0_206
# Processing block: ttk_sn _251
# Processing block: ttk_ssn_266
# Processing block: ttk_tft_283
# Processing block: ttk_tks_282
# Processing block: ttk_xrl_289
# Processing block: ttm_akl_280
# Processing block: ttm_ast_298
# Processing block: ttm_jst_249
# Processing block: ttm_n t_261
# Processing block: ttm_pp _216
# Processing block: ttm_rmn_294
# Processing block: ttm_rpn_278
# Processing block: ttn_jsm_209
# Processing block: ttn_kf _236
# Processing block: ttn_kns_210
# Processing block: ttn_lsf_231
# Processing block: ttn_rpr_277
# Processing block: ttp_ tf_201
# Processing block: ttp_a a_287
# Processing block: ttp_ark_266
# Processing block: ttp_krf_286
# Processing block: ttp_lk _231
# Processing block: ttp_lps_219
# Processing block: ttp_prn_220
# Processing block: ttp_rkf_234
# Processing block: ttp_sr _261
# Processing block: ttp_st_209
# Processing block: ttp_st_223
# Processing block: ttp_st_253
# Processing block: ttp_st_281
# Processing block: ttp_tf _201
# Processing block: ttp_tm _214
# Processing block: ttp_tm0_254
# Processing block: ttr_ak _265
# Processing block: ttr_kmp_299
# Processing block: ttr_mkl_221
# Processing block: ttr_ml _293
# Processing block: ttr_xlt_296
# Processing block: tts_ans_282
# Processing block: tts_ant_237
# Processing block: tts_ant_292
# Processing block: tts_f0 _250
# Processing block: tts_kfn_253
# Processing block: tts_krk_208
# Processing block: tts_krn_213
# Processing block: tts_lsl_286
# Processing block: tts_mis_208
# Processing block: tts_prj_268
# Processing block: tts_rnj_293
# Processing block: tts_rsl_230
# Processing block: tts_rsl_235
# Processing block: tts_rt _283
# Processing block: tts_rt_266
# Processing block: tts_spn_227
# Processing block: tts_str_224
# Processing block: tts_tn _207
# Processing block: ttt_ mk_206
# Processing block: ttt_ sm_296
# Processing block: ttt_ tf_278
# Processing block: ttt__289
# Processing block: ttt_als_220
# Processing block: ttt_als_228
# Processing block: ttt_als_248
# Processing block: ttt_als_268
# Processing block: ttt_apr_284
# Processing block: ttt_axl_214
# Processing block: ttt_flp_282
# Processing block: ttt_jms_218
# Processing block: ttt_kfn_235
# Processing block: ttt_kpl_282
# Processing block: ttt_kr _201
# Processing block: ttt_ls _245
# Processing block: ttt_luc_249
# Processing block: ttt_prn_257
# Processing block: ttt_prt_223
# Processing block: ttt_prt_226
# Processing block: ttt_ptr_274
# Processing block: ttt_s0 _238
# Processing block: ttt_trn_272
# Processing block: x l_tlr_245
# Processing block: x p_prn_211
# Processing block: x_krs_274
# Processing block: x_mis_215
# Processing block: x_mlr_217
# Processing block: x_t s_295
# Processing block: x_tmp_209
# Processing block: xf _nt _273
# Processing block: xfr_alm_244
# Processing block: xfr_bro_249
# Processing block: xfr_knn_258
# Processing block: xfr_krs_264
# Processing block: xfr_m0 _253
# Processing block: xfr_nt _204
# Processing block: xfr_nt _230
# Processing block: xfr_nt _244
# Processing block: xfr_tft_285
# Processing block: xfr_tn _217
# Processing block: xfs_alk_209
# Processing block: xfs_ars_216
# Processing block: xfs_ast_206
# Processing block: xfs_jn _230
# Processing block: xfs_jns_230
# Processing block: xfs_mrt_210
# Processing block: xfs_new_219
# Processing block: xfs_prn_227
# Processing block: xfs_rsl_260
# Processing block: xfs_sm0_211
# Processing block: xfs_sur_223
# Processing block: xkf_prn_205
# Processing block: xl _alm_219
# Processing block: xl _alm_241
# Processing block: xl _alm_292
# Processing block: xl _ast_216
# Processing block: xl _fr _223
# Processing block: xl _kmf_263
# Processing block: xl _kmp_246
# Processing block: xl _kmp_258
# Processing block: xl _tpt_224
# Processing block: xlk_atk_251
# Processing block: xls_jnf_270
# Processing block: xls_jnf_280
# Processing block: xls_jnf_281
# Processing block: xls_jnf_282
# Processing block: xlt_ _211
# Processing block: xlt_alm_241
# Processing block: xlt_axl_273
# Processing block: xlt_dan_267
# Processing block: xlt_nxl_263
# Processing block: xlt_r0 _218
# Processing block: xmp_mrk_273
# Processing block: xmp_prt_290
# Processing block: xmt_ kr_292
# Processing block: xmt_frn_246
# Processing block: xmt_frt_209
# Processing block: xmt_rtn_282
# Processing block: xmt_str_289
# Processing block: xmt_tfs_201
# Processing block: xmt_tm0_288
# Processing block: xn _ js_210
# Processing block: xn _ js_217
# Processing block: xn _ js_224
# Processing block: xn _an0_243
# Processing block: xn _cay_251
# Processing block: xn _mj _221
# Processing block: xn _ray_208
# Processing block: xn _sm0_240
# Processing block: xnk_slm_252
# Processing block: xnn_a p_260
# Processing block: xnn_a x_239
# Processing block: xnn_a x_299
# Processing block: xnn_ast_224
# Processing block: xnn_jn _230
# Processing block: xnn_jnk_273
# Processing block: xnn_jsn_223
# Processing block: xnn_jsn_227
# Processing block: xnn_jsn_282
# Processing block: xnn_jsn_293
# Processing block: xnn_klt_203
# Processing block: xnn_knt_223
# Processing block: xnn_krt_262
# Processing block: xnn_ktl_287
# Processing block: xnn_mrt_232
# Processing block: xnn_pat_208
# Processing block: xnn_prk_234
# Processing block: xnn_prk_238
# Processing block: xnn_prk_242
# Processing block: xnn_prt_226
# Processing block: xnn_ptr_208
# Processing block: xnn_rpn_218
# Processing block: xnn_rpn_231
# Processing block: xnn_rpn_283
# Processing block: xnn_rpr_230
# Processing block: xnn_smn_200
# Processing block: xnn_smn_218
# Processing block: xnn_smn_272
# Processing block: xnn_smn_299
# Processing block: xnn_snt_291
# Processing block: xnn_x k_266
# Processing block: xnn_xnf_290
# Processing block: xnp_krs_276
# Processing block: xnt_a n_268
# Processing block: xnt_mls_205
# Processing block: xnt_mrk_235
# Processing block: xnt_mrk_281
# Processing block: xnt_prt_248
# Processing block: xnt_tlr_261
# Processing block: xpm_jsf_299
# Processing block: xpm_rpk_289
# Processing block: xpr_prn_232
# Processing block: xpr_prn_263
# Processing block: xpr_prn_269
# Processing block: xpr_prn_295
# Processing block: xr _als_212
# Processing block: xr _als_225
# Processing block: xr _als_239
# Processing block: xr _als_240
# Processing block: xr _als_273
# Processing block: xr _als_281
# Processing block: xr _als_282
# Processing block: xr _ant_216
# Processing block: xr _hrt_287
# Processing block: xr _jn _250
# Processing block: xr _jn _271
# Processing block: xr _prt_266
# Processing block: xr _tls_268
# Processing block: xr_als_219
# Processing block: xrl_aa _281
# Processing block: xrl_ark_290
# Processing block: xrl_ast_208
# Processing block: xrl_ast_269
# Processing block: xrl_ast_270
# Processing block: xrl_ast_274
# Processing block: xrl_atm_217
# Processing block: xrl_atm_225
# Processing block: xrl_atm_226
# Processing block: xrl_atm_236
# Processing block: xrl_atm_271
# Processing block: xrl_dan_283
# Processing block: xrl_jn _210
# Processing block: xrl_jn _261
# Processing block: xrl_js_222
# Processing block: xrl_jt _253
# Processing block: xrl_jt _291
# Processing block: xrl_jt _296
# Processing block: xrl_kn0_205
# Processing block: xrl_knr_212
# Processing block: xrl_kr _201
# Processing block: xrl_lk _238
# Processing block: xrl_lk_238
# Processing block: xrl_ls _212
# Processing block: xrl_mos_243
# Processing block: xrl_mrk_213
# Processing block: xrl_nln_291
# Processing block: xrl_prs_205
# Processing block: xrl_prt_257
# Processing block: xrl_ptr_215
# Processing block: xrl_ptr_223
# Processing block: xrl_rxr_220
# Processing block: xrl_rxr_282
# Processing block: xrl_rxr_289
# Processing block: xrl_sm _213
# Processing block: xrl_sml_238
# Processing block: xrl_tft_265
# Processing block: xrl_tft_278
# Processing block: xrl_xlt_230
# Processing block: xrl_xlt_235
# Processing block: xrl_xlt_245
# Processing block: xrl_xlt_270
# Processing block: xrl_xlt_292
# Processing block: xrm_mls_262
# Processing block: xrm_rt _273
# Processing block: xrm_tnk_273
# Processing block: xrn_jn0_224
# Processing block: xrn_prn_217
# Processing block: xrp_als_268
# Processing block: xrp_rt _253
# Processing block: xrp_wri_279
# Processing block: xrt_akn_241
# Processing block: xrt_alm_207
# Processing block: xrt_flp_243
# Processing block: xrt_jns_203
# Processing block: xrt_jns_212
# Processing block: xrt_jsk_201
# Processing block: xrt_khn_264
# Processing block: xrt_l p_295
# Processing block: xrt_rt _203
# Processing block: xrt_rt _278
# Processing block: xrx_jns_203
# Processing block: xs _wil_273
# Processing block: xt _hmp_291
# Processing block: xt _jx _244
# Processing block: xt _rjn_216
# Processing block: xt _rjn_242
# Processing block: xt _rjn_258
# Processing block: xt _rjn_281
# Processing block: xt _rjn_283
# Processing block: xt _srr_250
# Processing block: xt _xmp_213
# Processing block: xt _xmp_232
# Processing block: xt _xmp_270
# Processing block: xt _xmp_279

# %%
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt

# Verifica las dimensiones de la matriz de similitud
print(f"Dimensiones de la matriz de similitud: {similarity_matrix.shape}")

# Asegúrate de que la matriz de similitud cubra todas las transacciones en final_df
if similarity_matrix.shape[0] != final_df.shape[0]:
    print("El número de transacciones en 'final_df' no coincide con la matriz de similitud.")
else:
    # Asegúrate de que no haya NaN en la matriz de similitud
    similarity_matrix_clean = np.nan_to_num(similarity_matrix)  # Reemplaza NaN por 0 o valor adecuado

    # Realizar PCA (reducción de dimensionalidad)
    pca = PCA(n_components=2)
    reduced_data = pca.fit_transform(similarity_matrix_clean)

    # Verifica que las dimensiones de reduced_data coinciden con final_df
    print(f"Dimensiones de final_df: {final_df.shape}")
    print(f"Dimensiones de reduced_data: {reduced_data.shape}")

    # Si las dimensiones coinciden, asigna las columnas PCA al DataFrame final
    if final_df.shape[0] == reduced_data.shape[0]:
        final_df['pca_x'] = reduced_data[:, 0]
        final_df['pca_y'] = reduced_data[:, 1]

        # Graficar los clusters
        plt.figure(figsize=(10, 8))
        sns.scatterplot(
            data=final_df,
            x='pca_x',
            y='pca_y',
            hue='external_id',  # Usar 'external_id' para los colores
            palette='viridis',
            legend=None
        )
        plt.title('Visualización de Clusters')
        plt.show()
    else:
        print("Las dimensiones de final_df y reduced_data no coinciden. Verifica la alineación de los datos.")
print(f"Dimensiones de final_df: {final_df.shape}")
# Out:
# Dimensiones de la matriz de similitud: (2, 2)
# El número de transacciones en 'final_df' no coincide con la matriz de similitud.
# Dimensiones de final_df: (11064, 15)

# %%
# Visualizar el tamaño de cada cluster
cluster_sizes = final_df['external_id'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=cluster_sizes.index, y=cluster_sizes.values)
plt.title('Distribución de Clusters')
plt.xlabel('Cluster ID')
plt.ylabel('Tamaño del Cluster')
plt.show()
# Out:
# <Axes: xlabel='external_id'>
# Text(0.5, 1.0, 'Distribución de Clusters')
# Text(0.5, 0, 'Cluster ID')
# Text(0, 0.5, 'Tamaño del Cluster')

# %%
import jellyfish  # Para similitudes como Jaro-Winkler
from fuzzywuzzy import fuzz  # Para similitudes adicionales, si necesario

# Función para calcular similitudes entre dos nombres
def name_similarity(name1, name2):
    # Utilizamos Jaro-Winkler para calcular la similitud de los nombres
    return jellyfish.jaro_winkler(name1, name2)

# Función para calcular similitud entre dos números de teléfono
def phone_similarity(phone1, phone2):
    return phone1 == phone2  # Comparación exacta después del preprocesamiento

# Función para comparar códigos postales
def postal_code_similarity(code1, code2):
    return code1 == code2  # Comparación exacta

# Crear función para calcular similitudes generales entre los pares
def calculate_similarities(df, pairs):
    similarities = []
    
    for pair in pairs:
        idx1, idx2 = pair
        row1, row2 = df.loc[idx1], df.loc[idx2]
        
        # Calcular la similitud de nombres
        name_sim = name_similarity(row1['parsed_name'], row2['parsed_name'])
        
        # Calcular la similitud de teléfonos
        phone_sim = phone_similarity(row1['party_phone'], row2['party_phone'])
        
        # Calcular la similitud de códigos postales
        postal_sim = postal_code_similarity(row1['postal_code'], row2['postal_code'])
        
        # Podríamos ponderar las similitudes si es necesario (por ejemplo, más peso al nombre)
        total_similarity = (name_sim * 0.7) + (phone_sim * 0.2) + (postal_sim * 0.1)
        
        similarities.append(total_similarity)
    
    return similarities

# Calcular las similitudes para los pares generados
similarities = calculate_similarities(merged_df, pairs)

# Mostrar algunas de las similitudes calculadas
similarities[:10]  # Primeros 10 resultados
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 42
#      39     return similarities
#      41 # Calcular las similitudes para los pares generados
# ---> 42 similarities = calculate_similarities(merged_df, pairs)
#      44 # Mostrar algunas de las similitudes calculadas
#      45 similarities[:10]  # Primeros 10 resultados
#
# NameError: name 'pairs' is not defined

# %%
from itertools import combinations

# Verificar si la columna block_key existe
if 'block_key' not in merged_df.columns:
    raise ValueError("La columna 'block_key' no existe en el DataFrame. Verifica tus datos.")

# Asegurarse de que no haya valores nulos en block_key
if merged_df['block_key'].isnull().any():
    raise ValueError("La columna 'block_key' contiene valores nulos. Por favor, maneja esos casos.")

# Generar pares de transacciones dentro de cada bloque
def create_pairs(df, block_column):
    pairs = []
    for key, block in df.groupby(block_column):
        block_pairs = list(combinations(block.index, 2))  # Combinaciones dentro del bloque
        pairs.extend(block_pairs)
    return pairs

# Crear los pares usando el 'block_key' fonético
pairs = create_pairs(merged_df, 'block_key')

# Mostrar algunos pares para verificar
print(f"Total de pares generados: {len(pairs)}")
print("Primeros 10 pares:")
print(pairs[:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 5
#       3 # Verificar si la columna block_key existe
#       4 if 'block_key' not in merged_df.columns:
# ----> 5     raise ValueError("La columna 'block_key' no existe en el DataFrame. Verifica tus datos.")
#       7 # Asegurarse de que no haya valores nulos en block_key
#       8 if merged_df['block_key'].isnull().any():
#
# ValueError: La columna 'block_key' no existe en el DataFrame. Verifica tus datos.

# %% [markdown]
# ### 1.1 Pre-processing of the variable parsed_name

# %%
# Delete honorifics from the names

# Sample data for demonstration
merged_data_cleaned2 = pd.DataFrame({
    'transaction_reference_id': [1, 2, 3, 4, 5],
    'parsed_name': ['Mr. John Doe', 'Dr. Jon Doe', 'Ms. Jane Doe', 'Jonny Doe', 'Prof. Sonya Sonya'],
    'postal_code': ['12345', '12345', '67890', '67891', '67892']
})

def delete_honorifics(name): 
    name['parsed_name'] = name['parsed_name'].str.replace('Mr. ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Ms. ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Mrs. ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Miss ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Dr. ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Prof. ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Rev. ', '')
    name['parsed_name'] = name['parsed_name'].str.replace('Hon. ', '')

delete_honorifics(merged_data_cleaned2)
print(merged_data_cleaned2)
# Out:
#    transaction_reference_id  parsed_name postal_code
# 0                         1     John Doe       12345
# 1                         2      Jon Doe       12345
# 2                         3     Jane Doe       67890
# 3                         4    Jonny Doe       67891
# 4                         5  Sonya Sonya       67892

# %%
# Normalize the names

def normalize_names(name):
    name['parsed_name'] = name['parsed_name'].str.lower()

normalize_names(merged_data_cleaned2)
print(merged_data_cleaned2)
# Out:
#    transaction_reference_id  parsed_name postal_code
# 0                         1     john doe       12345
# 1                         2      jon doe       12345
# 2                         3     jane doe       67890
# 3                         4    jonny doe       67891
# 4                         5  sonya sonya       67892

# %%
# Delete duplicates in the names

# Function to delete duplicated words in names
def delete_duplicates(name):
    def remove_duplicates(text):
        words = text.split()
        seen = set()
        result = []
        for word in words:
            if word.lower() not in seen:
                seen.add(word.lower())
                result.append(word)
        return ' '.join(result)
    
    name['parsed_name'] = name['parsed_name'].apply(remove_duplicates)
    return name

delete_duplicates(merged_data_cleaned2) 
print(merged_data_cleaned2)
# Out:
#    transaction_reference_id parsed_name postal_code
# 0                         1    john doe       12345
# 1                         2     jon doe       12345
# 2                         3    jane doe       67890
# 3                         4   jonny doe       67891
# 4                         5       sonya       67892
#    transaction_reference_id parsed_name postal_code
# 0                         1    john doe       12345
# 1                         2     jon doe       12345
# 2                         3    jane doe       67890
# 3                         4   jonny doe       67891
# 4                         5       sonya       67892

# %%
print(merged_data_cleaned2.columns)
# Out:
# Index(['transaction_reference_id', 'parsed_name', 'postal_code'], dtype='object')

# %%
import networkx as nx
from sklearn.metrics import pairwise_distances
from sklearn.feature_extraction.text import TfidfVectorizer
#from jellyfish import jaro_winkler_similarity
import pandas as pd
import fuzzy

# Initialize Soundex or Metaphone
metaphone = fuzzy.nysiis  # Uncomment this line to use Metaphone

# Step 2: Indexing (blocking) using Soundex or Metaphone
def create_block_key(name):
    metaphone_code = metaphone(name)  
    return metaphone_code

# Create block keys
#merged_data_cleaned2['block_key'] = merged_data_cleaned2.apply(lambda row: create_block_key(row['parsed_name']), axis=1)

#print(merged_data_cleaned2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import networkx as nx
#       2 from sklearn.metrics import pairwise_distances
#       3 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ModuleNotFoundError: No module named 'networkx'

# %%
def split_and_metaphone(full_name):
    """
    Divide un nombre completo en sus partes (palabras), aplica Metaphone a cada parte,
    y las junta nuevamente con espacios.
    """
    if pd.isna(full_name) or not isinstance(full_name, str):  
        return np.nan

    parts = full_name.strip().split()

    return ' '.join(create_block_key(part) for part in parts)

# Apply the function to the 'parsed_name' column
merged_data_cleaned2['block_key'] = merged_data_cleaned2['parsed_name'].apply(split_and_metaphone)
print(merged_data_cleaned2)
# Out:
#    transaction_reference_id parsed_name postal_code block_key
# 0                         1    john doe       12345     JAN D
# 1                         2     jon doe       12345     JAN D
# 2                         3    jane doe       67890     JAN D
# 3                         4   jonny doe       67891    JANY D
# 4                         5       sonya       67892       SAN

# %% [markdown]
# ### 1.2 Phone pre-processing

# %%
# Phone number normalization

combined_data['party_phone'] = combined_data['party_phone'].str.split('x').str[0]
combined_data['party_phone'] = combined_data['party_phone'].replace(r'\D', '', regex=True)
combined_data['party_phone'] = combined_data['party_phone'].str.lstrip('0')

data = combined_data[['party_phone']]
print(data)
# Out:
#           party_phone
# 0                 NaN
# 1        419477655328
# 2                 NaN
# 3       4119006262567
# 4                 NaN
# ...               ...
# 11059  13445497715686
# 11060   4116282024224
# 11061             NaN
# 11062             NaN
# 11063  51473539600789
#
# [11064 rows x 1 columns]

# %%
# Paso 3: Construcción del grafo
graph = nx.Graph()

# Agregar nodos
for idx, row in data.iterrows():
    node_id = row['transaction_reference_id']
    graph.add_node(node_id, attributes=row)

# Agregar aristas basadas en similitud
for node1, node2 in possible_pairs:  # Comparar dentro de cada bloque
    sim_name = jaro_winkler_similarity(graph.nodes[node1]['attributes']['parsed_name'],
                                       graph.nodes[node2]['attributes']['parsed_name'])
    if sim_name > 0.8:
        graph.add_edge(node1, node2)

# Paso 4: Identificar componentes conexos
clusters = list(nx.connected_components(graph))

# Paso 5: Asignar IDs de cluster
cluster_mapping = {node: cluster_id for cluster_id, cluster in enumerate(clusters) for node in cluster}
data['external_id'] = data['transaction_reference_id'].map(cluster_mapping)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/UBS_Lauzhack/usb_lauz/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transaction_reference_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 6
#       4 # Agregar nodos
#       5 for idx, row in data.iterrows():
# ----> 6     node_id = row['transaction_reference_id']
#       7     graph.add_node(node_id, attributes=row)
#       9 # Agregar aristas basadas en similitud
#
# File ~/Desktop/UBS_Lauzhack/usb_lauz/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~/Desktop/UBS_Lauzhack/usb_lauz/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~/Desktop/UBS_Lauzhack/usb_lauz/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'transaction_reference_id'
